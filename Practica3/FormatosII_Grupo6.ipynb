# %% [markdown]
# ### Práctica de Formatos de datos: XML

# %% [markdown]
# El objetivo de esta práctica es crear una aplicación que gestionará información sobre los restaurantes de la ciudad de Madrid.
#
# Para ello se va a usar el catálogo "Restaurantes con perfil turístico de la ciudad de Madrid" del portal de datos abiertos del Ayuntamiento de Madrid. El conjunto de datos incluye información sobre restaurantes de la ciudad de Madrid divididos por tipos de cocina, especialidades, servicios, etc. Así mismo, se incluyen los datos básicos de cada punto, una descripción, su geoposición y dirección postal, así como un conjunto de fotografías relativas a cada punto. En los casos en los que aplica, se ofrecen horarios de apertura y costes de acceso si los tuviera.
# La información se encuentra en:
# https://datos.madrid.es/sites/v/index.jsp?vgnextoid=ce33a73970504510VgnVCM2000001f4a900aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD
#
# Y el conjunto de datos XML que hay que procesar está situado en:
# https://datos.madrid.es/egob/catalogo/300033-10037079-turismo-restauracion.xml
#
# Junto al enunciado de la práctica se proporciona el fichero xml a tratar. El siguiente trozo de código permite recuperar el archivo xml en cuestion, y mostrar su contenido.

# %%
from xml.etree import ElementTree
from xml.dom import minidom
def prettify(elem):
    """Return a pretty-printed XML string for the Element."""
    rough_string=ElementTree.tostring(elem,"utf-8")
    reparsed=minidom.parseString(rough_string)
    return reparsed.toprettyxml(indent="  ")

f=open("restaurantes_v1_es.xml","rt",encoding="utf8")
arbol=ElementTree.parse(f)
raiz=arbol.getroot()


print (prettify(raiz))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# __Ejercicio 1 [5 puntos]__
#
# Se pide mostrar al usuario un listado de los nombres de los restaurantes que contiene el archivo con el objetivo de que elija un restaurante y se le muestre de forma amigable(sin etiquetas) por pantalla la información asociada al restaurante que se encuentra en el fichero recuperado:
#
# * Nombre del restaurante: etiqueta name
# * Email: etiqueta email
# * Teléfono: etiqueta phone
# * Descripción: etiqueta body
# * Página web: etiqueta web
# * Dirección: etiqueta address, etiqueta zipcode
# * Horario: etiqueta horario
# * Tipo de cocina: etiqueta Tipo
#
#
# A continuación se le pedira si quiere ver fotos del restaurante, en tal caso se le mostrarán las fotos recuperadas del restaurante. Para mostrar las imagenes puedes usar un trozo de código similar al siguiente.

# %%
import html
import re

def limpiar(texto: str):
    x = None
    if texto:
        x = re.sub("<.*?>", "", html.unescape(texto)) 
    return x

# %%
def sacar_lista_restaurante():
    return list(arbol.findall("./service"))

# %%
def mostrar_lista(lista_restaurante):
    i = 0
    for restaurante in lista_restaurante:
        print(str(i+1), limpiar(restaurante.find("basicData/name").text))
        i+=1

# %%
def print_custom(salida):
  print(salida or 'Desconocido')

def print_dir(addr='', provin=' Madrid ', zcode=''):
  print(addr + provin + zcode)

# %%
def mostrar_categorias(r):
  print('Tipo de cocina: ')
  for categoria in r.findall('extradata/categorias/categoria'):#En cada categoria
    nombre = ''
    subcategorias = list()
    for im in categoria.iter('item'): #Nombre de categoria
      if im.get('name') == 'Categoria':
                nombre = im.text
    for sub in categoria.findall('subcategorias/subcategoria/item'):#subacategorias
      if sub.get('name') == 'SubCategoria':  
        subcategorias.append(sub.text)
        
    subcategorias = ",".join(subcategorias)
    if subcategorias: #Distinción de caso , si hay subcategorias o no
      print(nombre,':', subcategorias)
    else:
      print(nombre)

# %%
def mostrar_restaurante(r):
    print("Nombre: ", )
    print_custom(limpiar(r.find("basicData/name").text))
    print("E-mail: ")
    print_custom(limpiar(r.find("basicData/email").text))
    print("Teléfono: ")
    print_custom(limpiar(r.find("basicData/phone").text))
    print("Descripción: ", )
    print_custom(limpiar(r.find("basicData/body").text))
    print("Página web: ", )
    print_custom(limpiar(r.find("basicData/web").text))
    print('Localizacion: ')
    print_dir(limpiar(r.find("geoData/address").text), '.Madrid, ', limpiar(r.find("geoData/zipcode").text))

    mostrar_categorias(r)
    horario = ''
    for n in  r.findall("extradata/item"):
        if n.get('name') == 'Horario':
            horario = n
    print("Horario: ", limpiar(horario.text))

# %%
from skimage import io
def mostrar_foto(r):
  for img in r.findall('multimedia/media/url'):
    img_src = img.text
    image = io.imread(img_src)
    io.imshow(image)
    io.show()

# %%
def menu():
    repet = True
    while(repet):
        lista_restaurante = sacar_lista_restaurante()
        mostrar_lista(lista_restaurante)
        restaurante = int(input("Introduzca el restaurante por su número correspondiente: ")) - 1 #Para usuario , el indice empieza con 1
        mostrar_restaurante(lista_restaurante[restaurante])
        foto = input("¿Mostrar foto? S/N: ")
        if foto == 'S':
            mostrar_foto(lista_restaurante[restaurante])
        repet = "S" == input("¿Repetir la búsqueda? S/N: ")

# %%
menu()
# Out:
# 1 Robuchon España
# 2 Abbasïd
# 3 El Lince
# 4 Hasaku Nikkei
# 5 La Negra Tomasa
# 6 Desde 1911
# 7 Papagena
# 8 RavioXO
# 9 Inclán Brutal Bar
# 10 DSPEAK
# 11 Mad Gourmets
# 12 Zen Noodle Bar
# 13 ZEN Asian Supper Club
# 14 Madame Butterfly
# 15 Bakan
# 16 Sagrario Tradición
# 17 Garelos
# 18 NOI
# 19 Vinoteca Moratín
# 20 Casa Mortero
# 21 Taberna Úbeda
# 22 Quimbaya
# 23 Trattoria Adriana
# 24 La Única
# 25 Commodore Madrid
# 26 La más croqueta
# 27 El Taller
# 28 Miss Sushi
# 29 La Terraza del Santo Domingo
# 30 MO de Movimiento
# 31 Coquetto Bar
# 32 Shukran City Ventas
# 33 Santa y Pura
# 34 Mune Madrid
# 35 Leña
# 36 Smoked Room
# 37 Barbecho
# 38 Diurno
# 39 Deessa
# 40 Villa Verbena
# 41 Citynizer Plaza
# 42 Barracuda MX
# 43 Aloha Poké
# 44 Tripea
# 45 Castelados
# 46 La Maruca
# 47 La MaMá Restaurante
# 48 Quinqué
# 49 Saddle
# 50 Bocanegra
# 51 Dani Brasserie
# 52 Bloom
# 53 La Venencia
# 54 Gran Vía 55
# 55 Bodega de La Ardosa
# 56 Casa Julio
# 57 Casa Camacho
# 58 Bodegas Ricla
# 59 Bar Santurce
# 60 Tablafina
# 61 Patio de Leones
# 62 Prístino
# 63 Neotaberna Santerra
# 64 Estimar
# 65 Ovillo
# 66 Restaurante  La Tajada
# 67 Restaurante Ponzano
# 68 Berlanga
# 69 Hermanos Vinagre
# 70 Válgame Dios
# 71 Maddock
# 72 Yugo the Bunker
# 73 Gofio by Cicero Canary
# 74 99 KŌ Sushi Bar
# 75 Restaurante Casa Pepe 1899
# 76 Landareak
# 77 La Huerta de Almería
# 78 B13
# 79 Chilling Cafe
# 80 Hakuna Matata Veggie
# 81 Cookaluzka
# 82 Bunny's Deli
# 83 Vega
# 84 Distrito Vegano Invernadero
# 85 Run Run Run
# 86 Occhiali
# 87 Colósimo
# 88 Aitatxu
# 89 Hong Kong 70
# 90 Zest
# 91 Salutteria
# 92 Indalo Tapas
# 93 Casa Lolea
# 94 Kippu
# 95 El Clásico
# 96 Xantar Astur
# 97 Alma Cocktails & Tapas
# 98 Pólvora
# 99 La Ventana de Flavia
# 100 La Casita de Sabino
# 101 Flora Fina
# 102 Da Luca Trattoria - Pizzeria
# 103 Caraba
# 104 Avocado Love
# 105 El Mirador del Olivar
# 106 Azotea Forus Barceló
# 107 Chigre
# 108 Hermanas Arce
# 109 Las Carboneras de Lu
# 110 Chido Castizo & Chingón
# 111 La Elegida
# 112 La Tasca del Retiro
# 113 Barra y Mantel
# 114 Marabú
# 115 La Cocina de Frente
# 116 Aüakt
# 117 El 5 de Tirso
# 118 Casa Julián de Tolosa (Ibiza)
# 119 El Jefe Traveling Food
# 120 La Carlota
# 121 La Veritá
# 122 Pieology
# 123 Mesteño Bar
# 124 Guillermina
# 125 Casa Ciriaco
# 126 El Amor Hermoso Bar
# 127 Casa Candi
# 128 Raimunda
# 129 Monsieur Sushita
# 130 Sottosopra
# 131 Pez Fuego
# 132 Ferretería by EGO
# 133 Doña Truhana
# 134 Noname Bar
# 135 Taberna Bandido
# 136 Doña Luz
# 137 Sinsombrero
# 138 Pic&Nic
# 139 Hake Mate
# 140 Giulietta
# 141 Sukaldean Bai Bokado
# 142 Lamucca (Plaza del Carmen)
# 143 La Bientirada
# 144 Iztac
# 145 Taberna El Gallocanta
# 146 Green Tea Food & Drinks
# 147 Ikigai
# 148 Enigmatium Room
# 149 La Madreña (Paseo de la Castellana)
# 150 Picalagartos Sky - Bar
# 151 Teje Maneje
# 152 Lambuzo (Retiro)
# 153 Yakiniku Rikyu
# 154 Yan Ken Pon
# 155 Shanghai mama (Cuzco)
# 156 Quispe
# 157 Les Mauvais Garçons
# 158 Hot Now
# 159 Dogma
# 160 Charrúa
# 161 Soma by Luke
# 162 Tasty Poke Bar
# 163 Como en Chile
# 164 San Wich
# 165 Restaurante Masterchef
# 166 Nudista
# 167 Arado. Grocery & Restaurant
# 168 Tres por Cuatro
# 169 Propaganda 12
# 170 Pomerania
# 171 Misska
# 172 Mawey Taco Bar
# 173 Lobo 8
# 174 La Cebichería de Trafalgar
# 175 Falafeleria
# 176 Cilindro
# 177 Botania
# 178 Alameda
# 179 De la Riva
# 180 Donzoko
# 181 Callao24
# 182 Astrolabius
# 183 El Buda Feliz 1974
# 184 Shinatora Ya
# 185 La Sal del Mentidero
# 186 Cascorro Bistrot
# 187 Grosso Napoletano (Santa Engracia)
# 188 Vagalume
# 189 Cortezo Yatai Market
# 190 El Greco
# 191 El Oso
# 192 La Catapa
# 193 La Bien Aparecida
# 194 99 Sushi Bar (Padre Damián)
# 195 Ruta 77 Palacio de Hielo
# 196 Volvoreta
# 197 Bump Green
# 198 Étimo
# 199 Ninja Ramen
# 200 La Castañal
# 201 La Boiga Taberna
# 202 Taberna Averías
# 203 Casa Baranda
# 204 Hortensio
# 205 Kanbun Taberna Oriental
# 206 Carl’s JR.
# 207 Alzahra
# 208 Pizzi & Dixie
# 209 Montmartre 1889
# 210 Kuoco 360º food
# 211 Corral de la Morería Restaurante Gastronómico
# 212 Candeli
# 213 El cielo de Urrechu
# 214 Ottica Restaurante
# 215 El Cucurucho del Mar
# 216 Morgana
# 217 Gula Gula
# 218 Clos Madrid
# 219 Paperboy Perrito Bar
# 220 Crêperie La Rue
# 221 La Casa Tomada
# 222 Bangalore Modern Indian Cuisine
# 223 Picoroco
# 224 Derzu Bar
# 225 Haches
# 226 Taramara
# 227 Casa Maravillas
# 228 Gustos Madrid Plaza Mayor
# 229 Tapas Gratis El Biombo (Hogar Extremeño)
# 230 Restaurante de Casa de Castilla La Mancha en Madrid
# 231 Restaurante Xiongzai
# 232 Cafetería Lily
# 233 Japanese Club
# 234 Gran Café de Madrid
# 235 Zielou
# 236 Pink Monkey
# 237 Borax
# 238 Havana Blues
# 239 Cuando salí de Cuba
# 240 La Taberna de Elia
# 241 MAD13
# 242 La Porcinería
# 243 Restaurante Gourmand
# 244 Foodtruck
# 245 Las chicas, los chicos y los maniquís
# 246 Taberna La Elisa
# 247 Condumios Taberna
# 248 Graciela
# 249 Taberna Artesana Verdejo
# 250 Vaca Nostra
# 251 La Gamella
# 252 Beker 6
# 253 [A]Brasa
# 254 Lux Madrid
# 255 The One
# 256 Membibre
# 257 Fellina
# 258 Santerra
# 259 KIP
# 260 Superchulo
# 261 La Pavía
# 262 Amargo Place to Be
# 263 Rocacho
# 264 Apartaco
# 265 Tiendas de Señorío
# 266 Rawcoco Green Bar Madrid
# 267 Aduana
# 268 Shuwa Shuwa
# 269 Doli
# 270 Puerta de Atocha
# 271 La Madreña (Calle del Bronce)
# 272 As Fontes
# 273 Al Punto
# 274 El Velázquez 17
# 275 NiMÚ Barquillo
# 276 Sargo. El arrecife de Madrid
# 277 The Mint Roof
# 278 Taberna Recreo
# 279 Sushita Café - Miguel Angel
# 280 Marcano
# 281 Levél Veggie Bistro
# 282 Enigmatium
# 283 Latasia Casa de Comidas
# 284 Casa Jaguar
# 285 Flores de Alcachofa
# 286 Fábula Buey & Champagne
# 287 Arima Basque Gastronomy
# 288 ¡Tu! Pasta
# 289 Soy Kitchen
# 290 Kappo
# 291 Inti de Oro
# 292 Ralph’s
# 293 Steak Burger (Gran Vía)
# 294 La Panera Rosa
# 295 Sugarcane
# 296 Sky Sushi & Ramen Bar
# 297 Ramen Shifu
# 298 Peyote San
# 299 Numa Pompilio
# 300 Narciso Brasserie
# 301 Media Ración
# 302 La Encarna Bistró Andaluz
# 303 Chow Chow
# 304 Casa Suecia
# 305 Canalla Bistró
# 306 Art & Sushi
# 307 Arallo Taberna
# 308 Al Socaire
# 309 La Encomienda
# 310 Dos Cielos Madrid
# 311 La Clave
# 312 Dans le noir?
# 313 Madame Sushita
# 314 Honest Greens
# 315 Esplore
# 316 Restaurante de la Residencia de Estudiantes
# 317 Surya
# 318 Cruz Blanca de Vallecas
# 319 Radio Rooftop
# 320 Alfredo’s barbacoa
# 321 El Escondite de Villanueva
# 322 Reineta
# 323 La Primera
# 324 Somos
# 325 Timesburg
# 326 A' kangas by Urrechu
# 327 El Flaco
# 328 Kirei Las Cortes
# 329 Kirei Barajas
# 330 Lubora
# 331 El Imparcial
# 332 Sidrería El Tigre
# 333 GastroVía 61
# 334 Ojalá
# 335 La Taurina
# 336 Los Arcos de Ponzano
# 337 Huerta de Carabaña
# 338 Robin Hood
# 339 Taberna El Tempranillo
# 340 El Invernadero
# 341 Gaytán
# 342 A´Barra
# 343 Makkila
# 344 NuBel
# 345 Pointer
# 346 Five Guys
# 347 Angelita Madrid
# 348 Vila Brasil
# 349 Sacha
# 350 Alcuzcuz de Alhuzema
# 351 Cannibal Raw Bar
# 352 La Taberna Murciana
# 353 Restaurante Mutis
# 354 Jimbo Smokehouse
# 355 Garbel Madrid
# 356 Casa Macareno
# 357 Taberna & Media
# 358 La Malaje
# 359 Carlos Oyarbide
# 360 Amazónico
# 361 La Bekada
# 362 El soportal
# 363 Bistronomika
# 364 Bibo Madrid
# 365 Puertalsol
# 366 Sal Negra
# 367 Jack Percoca
# 368 Fismuler
# 369 Cebo
# 370 López & López
# 371 YOUnique
# 372 Lamian by Soy Kitchen
# 373 Habanera
# 374 Bar El Pescador
# 375 Bar Alonso Cervecería Marisquería
# 376 Casa Emilio
# 377 Le Petit Comité
# 378 La Estación de los Porches
# 379 La Carmencita
# 380 Florida Park
# 381 El Pelícano
# 382 La Matritense
# 383 Bodegas Rivas
# 384 Sifón
# 385 KultO
# 386 Taberna Pedraza
# 387 La Excéntrica
# 388 Oven Mozarella Bar
# 389 Premiata Fornería Ballaró
# 390 Taberna Degusta
# 391 Ramen Kagura
# 392 Antigua Taquería
# 393 El Rincón Guay
# 394 Mad Brewing
# 395 Lakook Casa Árabe
# 396 Xareu
# 397 Vinos 11 Casa Dani
# 398 La Raquetista
# 399 Palo Cortado
# 400 Maestro Food & More
# 401 Restaurante Elkuru
# 402 As Jamonería
# 403 Mandarín
# 404 Royal Cantonés
# 405 Kzen
# 406 China Té
# 407 Casa Lafu
# 408 Asia Té
# 409 Perrachica
# 410 La Vaquería Montañesa
# 411 La Charca
# 412 Floren Domezáin
# 413 La Vanduca
# 414 Benares
# 415 Da Giuseppina
# 416 Marina Ventura
# 417 Lúa
# 418 Ronda 14
# 419 Swagat
# 420 Cachivache
# 421 Docamar
# 422 La Canica
# 423 Sal Gorda
# 424 Taberna Los Gallos
# 425 Filandón
# 426 Kilómetros de pizza
# 427 Kirikata
# 428 Restaurante Navaja
# 429 Naia Bistro
# 430 Lambuzo (Conchas)
# 431 La Platería
# 432 La Palma 60
# 433 Toque de Sal
# 434 Arzabal (Reina Sofía)
# 435 Restaurante Etíope Hanan
# 436 ElMandela
# 437 La berenjena
# 438 La Bobia
# 439 La Pescadería
# 440 El puchero de mi abuela
# 441 Los Chanquetes
# 442 O Pazo de Lugo
# 443 La Giralda IV
# 444 La Giralda II
# 445 Bocadillo de Jamón y Champán (Fernando VI)
# 446 El Perro y La Galleta
# 447 Askuabarra
# 448 Gochü
# 449 Izariya
# 450 Punto Básico
# 451 Gioia
# 452 La peseta de Doña Casilda
# 453 Hattori Hanzo
# 454 Tatel
# 455 Ático
# 456 La Tasquería
# 457 Bar Galleta
# 458 El Columpio
# 459 Marieta
# 460 La Verónica
# 461 La Lonja del Mar
# 462 La Gloria de Montera
# 463 Atelier Belge
# 464 Salón de Tapas Plaza Mayor
# 465 Taberna Corrientes
# 466 Taste Gallery
# 467 Metro Bistro (Plaza Mayor)
# 468 Salón Cascabel
# 469 Picsa
# 470 Mama Campo
# 471 Desencaja
# 472 Bacira
# 473 Celso y Manolo
# 474 Tándem
# 475 Alabaster
# 476 Ana La Santa
# 477 Montia
# 478 La Cabra
# 479 Bosco de Lobos
# 480 Vietnam Mekong
# 481 StreetXO
# 482 Café Colón Madrid
# 483 DSTAgE Concept
# 484  Yakitoro
# 485 Platea Madrid
# 486 La Buga del Lobo
# 487 Miyama
# 488 Nakeima Dumpling Bar
# 489 80º
# 490 Matute 12
# 491 Arzábal Retiro
# 492 Sala de Despiece
# 493 Triciclo
# 494 Taj
# 495 La Rebonita
# 496 María Bonita Taco Bar (Duque de Liria)
# 497 Bodega de Los Secretos
# 498 Arahy
# 499 Los Chuchis
# 500 Zombie Bar
# 501 Aroy Thai
# 502 Saporem
# 503 Juanyta Me Mata
# 504 El Mandil
# 505 La huerta de Tudela
# 506 Fuente de la Fama
# 507 Tacos Chapultepec
# 508 Du Liban
# 509 Taberna Casa Curro
# 510 Donde Mónica
# 511 M29
# 512 Materia Prima
# 513 Terramundi
# 514 Chirón
# 515 Mentidero de la Villa Restaurante
# 516 Costello Río
# 517 Thai Orchid
# 518 Restaurante Maru
# 519 Muñagorri
# 520 Taberna del Chato
# 521 Asgaya
# 522 El Patio de la Central (La Central de Callao)
# 523 Casa Mono
# 524 La Revoltosa
# 525 Támara Restaurante Lorenzo
# 526 El Tendido
# 527 Camino Food & Drinks
# 528 El Bund
# 529 Chifa
# 530 La Caña
# 531 Gobu Burger
# 532 Murillo Café
# 533 Tommy Mel's
# 534 La Castafiore
# 535 La Rue
# 536 Restaurante Vegetariano
# 537 El Económico. Soidemersol.
# 538 Hare Krishna
# 539 La Chula de Chamberí
# 540 Taberna Dehesa Santa María
# 541 Sagardi (Euskal Etxea)
# 542 Gourmet Bar
# 543 Le Petit Prince
# 544 La Plaza
# 545 El rey de tallarines
# 546 Trattoria Pinocchio (Sánchez Bustillo)
# 547 Naif
# 548 Couzapín
# 549 Lakasa
# 550 Pulpería Vilalúa
# 551 Sagar
# 552 Cañadío
# 553 Seoul
# 554 Han Gang
# 555 Korea
# 556 Dimibang
# 557 Dionisos
# 558 García de la Navarra
# 559 Surtopía
# 560 Mérimée
# 561 La Botillería
# 562 Cafetería-restaurante Colección Cibeles
# 563 Restaurante Terraza Palacio de Cibeles
# 564 La Sureña
# 565 La Casa del Pulpo
# 566 Minotauro
# 567 La Pulperia de Mila
# 568 Trattoria SantArcangelo
# 569 El Buey
# 570 Los Remos
# 571 Bar Amor
# 572 El Puerto de Cabreira
# 573 100 Montaditos
# 574 Gumbo
# 575 Yuè Lái (Joya Oriental)
# 576 Bolívar
# 577 Luzi Bombón
# 578 Soma
# 579 Rustika Tapas & Gin
# 580 Vi Cool
# 581 Magasand
# 582 Al Fanus
# 583 Mr. Kabab
# 584 La Escudilla
# 585 Nuria
# 586 Yerbabuena
# 587 Esfahan
# 588 St. James
# 589 La Antoñita
# 590 New York Burger
# 591 Aynaelda
# 592 El Boquerón
# 593 El Jardín del InterContinental
# 594 Cheese Bar de Poncelet
# 595 El Estragón Vegetariano
# 596 La Esquina de Chamberí
# 597 Asador Gerardo
# 598 TxaTei
# 599 Kulixka
# 600 Zen Market
# 601 Fuku
# 602 Ten con Ten
# 603 11 Nudos Terraza Nordés
# 604 La Jauría
# 605 El Qüenco de Pepa
# 606 Pittu
# 607 El Almirez
# 608 Orio
# 609 Enotaberna del León de Oro
# 610 Majaderitos Café
# 611 Nuevo Gerardo
# 612 La Tita Rivera
# 613 Taberna Moncloa
# 614 Pintxos Elcano
# 615 Gobolem (San Francisco)
# 616 Gobolem (Julián Romea)
# 617 José Luis (General Oráa)
# 618 Gran Sol
# 619 La Tapería del Prado
# 620 José Luis (San Francisco)
# 621 La Montadería
# 622 El Rincón de Jaén (Doctor Gómez Ulla)
# 623 La Taberna del Capitán Alatriste
# 624 El Rincón de Jaén (Ramón de la Cruz)
# 625 El Rincón de Jaén (Camilo José Cela)
# 626 Casa Jorge (Cartagena)
# 627 Cazorla (Castelló)
# 628 Casa Victor
# 629 Cazorla (Montesa)
# 630 Cazorla (Cipriano Sancho)
# 631 El Jamón del Abuelo
# 632 Fortuny Home Club
# 633 El Decano
# 634 El Buti Taberna
# 635 El Circo de las Tapas
# 636 Casa Fidel
# 637 The Cask
# 638 Yamate
# 639 Mashita
# 640 Oishii Sushi & Ramen
# 641 Ikura
# 642 Hanakura
# 643 Naomi
# 644 Lamucca de Pez (Carlos Cambronero)
# 645 Maldonado 14
# 646 Asturianos
# 647 La Pesquera
# 648 Gala (Espronceda)
# 649 Verdil
# 650 Colonial Norte
# 651 Ferreiro (Paseo de la Florida)
# 652 Lamucca (Prado)
# 653 Furusato
# 654 Cafetería HD
# 655 Treze
# 656 Buenas y Santas (Bolívar)
# 657 La Barra de Garcilaso
# 658 Goizeko Kabi
# 659 Los Rotos
# 660 Los Arroces de Segis
# 661 Samm
# 662 Bahiana
# 663 Restaurante Jota
# 664 Jota Batela
# 665 El Cocinillas
# 666 Casa Toribio
# 667 Taberna La Daniela
# 668 Las Reses
# 669 Toma Jamón (Vergara)
# 670 Salterius
# 671 Mesón Gallego II
# 672 Mesón Gallego I
# 673 Taberna La Lirio
# 674 Grazie Mille Kitchen Bar
# 675 Azotea del Círculo
# 676 Pontepez
# 677 Más Jamón
# 678 Casa Pedro
# 679 Ogrelo
# 680 Entre Suspiro y Suspiro
# 681 Taberna Agrado
# 682 Dibocca
# 683 BLoved
# 684 La Guisandera de Piñera
# 685 T.G.I Fridays
# 686 El Cenador de Salvador
# 687 Casa José
# 688 Coque
# 689 La Dichosa
# 690 El Respiro
# 691 El Rincón de Goya
# 692 Los Cedros
# 693 Bar Tomate
# 694 Cervecería Sol Mayor
# 695 Lateral
# 696 Casa María
# 697 Casa Rua
# 698 Bar Postas
# 699 El Brillante
# 700 Valle Del Tietar
# 701 Liana 1962
# 702 Magerit
# 703 La Campana
# 704 La ideal
# 705 Home Burger Bar (Silva)
# 706 Alma Café
# 707 Mesón del Cid
# 708 La Gran Tasca
# 709 Asador de Sacramenia
# 710 Asador el Molinón
# 711 Carlos Tartiere
# 712 Los Montes de Galicia
# 713 Los Arrieros
# 714 L'Abbraccio
# 715 Kupela
# 716 Asador Pelotari
# 717 Jai Alai
# 718 La Favorita
# 719 Horno de Juan
# 720 Teitu
# 721 Ferreiro (Aviador Zorita)
# 722 El Espigón
# 723 Taberna Las Botas
# 724 La Perejila
# 725 Delic
# 726 Vegaviana
# 727 La Biotika
# 728 Artemisa
# 729 Los Timbales
# 730 Casa Paulino
# 731 Tandoori Station
# 732 Mercato Ballaró
# 733 Rasputín
# 734 Come Prima
# 735 The James Joyce
# 736 Centro Riojano
# 737 El Ñeru
# 738 Algarabía
# 739 El Caldero
# 740 "Tres Peces" El Ventorrillo Murciano
# 741 Casa Ricardo
# 742 Restaurante Esteban
# 743 La Vera
# 744 Villa de Foz
# 745 Compostela
# 746 Casa Adriano
# 747 Ponteareas
# 748 Rías Bajas
# 749 Carta Marina
# 750 Casa Nemesio
# 751 Casa de Valencia
# 752 Can Punyetes (Señores de Luzón)
# 753 Los Galayos
# 754 El Senador
# 755 Venta la Hidalguía
# 756 Asador Real
# 757 El Tormo
# 758 El Escaldón
# 759 Mallorca en Madrid
# 760 Restaurante Uval
# 761 La Gabinoteca
# 762 Ramón Freixa Madrid
# 763 La Tavernetta
# 764 99 Sushi Bar (Hermosilla)
# 765 Taquería del Alamillo
# 766 Casa Marco
# 767 Ginger
# 768 Krachai
# 769 Vesuvio
# 770 Olivia te cuida
# 771 Fass
# 772 Caripén
# 773 De Maria (Correo)
# 774 De María (Gran Vía)
# 775 De María (Hortaleza)
# 776 De María (Preciados)
# 777 De María (Félix Boix)
# 778 Beef Place
# 779 Entrevinos
# 780 La Cocina de María Luisa
# 781 Don Giovanni
# 782 La Montería
# 783 Puerto de Lagasca
# 784 Naveira do mar
# 785 Mestizo
# 786 Restaurante Villa Magna
# 787 La Buganvilla
# 788 El Mirador del Thyssen
# 789 Las Cuevas de Luis Candelas
# 790 Summa To Go
# 791 Nipon Taro
# 792 Ichiban
# 793 Ayala Japón
# 794 Inari
# 795 19 Sushi Bar
# 796 Kokoro
# 797 Ginza
# 798 Mikado
# 799 Taberna Alipio Ramos
# 800 La Tasca Suprema
# 801 99 Sushi Bar (Ponzano)
# 802 La Copla
# 803 Soy
# 804 La Ancha (Príncipe de Vergara)
# 805 Viavélez
# 806 La Buena Vida
# 807 Nicomedes
# 808 La Parra
# 809 El Café de la Ópera
# 810 Casa Narcisa
# 811 Bodegas Alfaro
# 812 Bodegas Rosell
# 813 La casa de las torrijas
# 814 Tienda de vinos (El comunista)
# 815 Stop Madrid
# 816 Tse Yang Villa Magna
# 817 La Penela
# 818 Viva Burger
# 819 El Cisne Azul
# 820 Janatomo
# 821 Albahía
# 822 Conache
# 823 Gaudium
# 824 El Sur
# 825 Malacatín
# 826 Casa Paco
# 827 Moncalvillo
# 828 Public
# 829 Clarita
# 830 Casa Perico
# 831 La Panza es Primero
# 832 La Mordida de Segovia
# 833 Sí Señor
# 834 Tepic
# 835 Estado Puro
# 836 Cervecería Plaza Mayor 2
# 837 La Esquina
# 838 Taberna Almería
# 839 Viejo Madrid
# 840 Restaurante UNO by Meliá Madrid Princesa
# 841 Ramses
# 842 Mercado de la Reina
# 843 Con Dos Fogones
# 844 El Fogón de Trifón
# 845 Cervecería Alemana
# 846 El Anciano Rey de los Vinos
# 847 El Cantábrico
# 848 La musa de Espronceda
# 849 Casa Manolo
# 850 Los Caracoles
# 851 Cangrejero
# 852 La Musa Latina
# 853 La Colonial de Goya
# 854 Maceiras (Huertas)
# 855 La cruzada
# 856 Taberneros
# 857 Las Bravas (Pje Matheu)
# 858 Matritum
# 859 Cervecería Cervantes
# 860 Maceiras (Jesús)
# 861 Huevos de Lucio
# 862 Taberna Ángel Sierra
# 863 Juana la Loca
# 864 Vinoteca Barbechera
# 865 Taberna Los Gatos
# 866 Baco y Beto
# 867 Las Bravas (Álvarez Gato)
# 868 Melo´s
# 869 Lamiak
# 870 La Tape
# 871 La Musa (Manuela Malasaña)
# 872 La Casa del Abuelo
# 873 La Camocha
# 874 La Castela
# 875 Mesón Cinco Jotas (Serrano)
# 876 Mesón Cinco Jotas  (Puigcerdá)
# 877 Jurucha
# 878 Mesón Cinco Jotas (Padre Damián)
# 879 José Luis (Pº de la Habana)
# 880  José Luis (Rafael Salgado)
# 881 José Luis (Serrano)
# 882 Taberna Cuenllas
# 883 Taberna de la Dolores
# 884 Estay
# 885 El Quinto Vino
# 886 Fide
# 887 Le Petit Hándicap
# 888 Vinos y tapas Pardiñas 25
# 889 Hevia
# 890 O´Caldiño
# 891 Sylkar
# 892 Sagaretxe
# 893 El Doble
# 894 Casa Revuelta
# 895 Restaurante Rafa
# 896 Taberna del Puerto
# 897 Casa Lucas
# 898 El Espejo
# 899 Taberna Almendro 13
# 900 Cervecería Santa Bárbara
# 901 Taberna Rayuela
# 902 De Partida
# 903 La Máquina de Chamberí
# 904 Rubaiyat  Madrid
# 905 El Paraguas
# 906 Puerta 57
# 907 Samarkanda
# 908 The Library Restaurant ( Santo Mauro, a Luxury Collection Hotel)
# 909 La Masía de José Luis
# 910 La Barraca
# 911 Asador de Aranda
# 912 Zerain
# 913 Zalacaín
# 914 Zara
# 915 Asia Gallery (The Westin Palace)
# 916 Asador Donostiarra
# 917 Horcher
# 918 Lhardy
# 919 Artys Madrid
# 920 Più di Prima
# 921 Casa Mingo
# 922 Casa Lucio
# 923 Casa Hortensia
# 924 Casa d'a Troya
# 925 Casa Carola
# 926 El Landó
# 927 Kabuki
# 928 Casa Julián de Tolosa (Cava Baja)
# 929 El Jardín de Orfila
# 930 Mesón Txistu
# 931 El Chaflán
# 932 Taberna del Alabardero
# 933 Bazaar
# 934 La Ancha (Zorrilla)
# 935 Al-Mounia
# 936 Restaurante Café de Oriente Museo del Traje
# 937 Goizeko Wellington
# 938 La Finca de Susana
# 939 Ecocentro
# 940 East 47
# 941 Casa Benigna
# 942 Hyragana (Vincci Soho)
# 943 Las Infantas
# 944 La Tasquita de Enfrente
# 945 Paco Roncero Restaurante
# 946 Viridiana
# 947 Café Saigón
# 948 Viuda de Vacas
# 949 Botín
# 950 La Bola
# 951 El Pescador
# 952 Mercado de Espronceda
# 953 Restaurante Las Cortes
# 954 La Hoja
# 955 Arce
# 956 Las Tortillas de Gabino
# 957 Gaztelupe
# 958 Taberna Antonio Sánchez
# 959 La Ópera de Madrid
# 960 Posada de la Villa
# 961 O'Pazo
# 962 Ricardo Sanz Wellington
# 963 DiverXO
# 964 Edelweiss
# 965 Casa Labra
# 966 Casa Alberto
# 967 Café de Oriente
# 968 Dantxari
# 969 Laredo
# 970 La Esquina del Real
# 971 La Rotonda (The Westin Palace)
# 972 Prada a Tope
# 973 Ox's
# 974 El Gran Barril
# 975 La Paloma
# 976 La Manduca de Azagra
# 977 Manolo
# 978 Real Café Bernabéu
# 979 Antigua Embajada (Hotel Palacio San Martín)
# 980 Café Varela Restaurante (Hotel Preciados)
# 981 Oliveros
# 982 El Rincón de Esteban
# 983 Allard Madrid
# 984 La Trainera
# 985 Paradís Madrid
# Introduzca el restaurante por su número correspondiente: 4
# Nombre:
# Hasaku Nikkei
# E-mail:
# Desconocido
# Teléfono:
# (+34) 91 210 54 43
# Descripción:
# La apuesta culinaria por la cocina nikkei del chef peruano Jhosef Arias se traduce en este restaurante situado en el barrio de Las Tablas. De estética minimalista, en él se puede disfrutar de la mezcla de dos culturas gastronómicas: la peruana y la japonesa, una de las muestras más notorias de la fusión cultural a través de la cocina.El nombre Hasaku proviene del japonés y hace referencia a una naranja agria e híbrida, que, en este caso, tiene relación con la lima y los cítricos, hilo conductor de la cocina peruana. Con este nombre se busca ofrecer una especie de reconocimiento y agradecimiento a la enorme influencia que supuso la inmigración y la cocina japonesa en la gastronomía peruana.Hasaku comenzó siendo un proyecto virtual llevado a cabo durante el cierre de los restaurantes por la pandemia provocada por la COVID-19, al que el chef dedicó muchas horas de experimentación.En su carta se pueden encontrar platos excepcionales que se pueden disfrutar tanto en el local como en casa gracias a su servicio de envio a domicilio. No disponen de menú diario pero sí de dos menús degustación con los platos más destacados de su propuesta gastronomíca.Arias se ha convertido en un referente de la gastronomía peruana en Madrid, donde cuenta con otros restaurantes: Piscomar, en Lavapiés; Humo, en Puente de Vallecas; Callao24, en Arturo Soria; y su más reciente creación, ADN Origen Perú, en la calle Mayor, junto al Mercado de San Miguel. En todos ellos ensalza distintos aspectos de la gastronomía de su tierra. No en vano forma parte de los 50 chefs del movimiento “Generación con Causa”, creado en Perú para promover la cocina peruana en el mundo, a través de la cuarta generación de cocineros, avalados por el reconocido chef peruano Gastón Acurio.
# Página web:
# https://www.esmadrid.com/restaurantes/hasaku-nikkei
# Localizacion:
# María Tubau, 17.Madrid, 28050
# Tipo de cocina:
# Internacional : Fusión,Internacional,Japonesa,Peruana
# Horario:  Mar – Sáb: 13:00 – 16:00h/20:00 – 01:00 hDomingo: 13:00 – 16:00 h
# ¿Mostrar foto? S/N: S
# ¿Repetir la búsqueda? S/N: S
# 1 Robuchon España
# 2 Abbasïd
# 3 El Lince
# 4 Hasaku Nikkei
# 5 La Negra Tomasa
# 6 Desde 1911
# 7 Papagena
# 8 RavioXO
# 9 Inclán Brutal Bar
# 10 DSPEAK
# 11 Mad Gourmets
# 12 Zen Noodle Bar
# 13 ZEN Asian Supper Club
# 14 Madame Butterfly
# 15 Bakan
# 16 Sagrario Tradición
# 17 Garelos
# 18 NOI
# 19 Vinoteca Moratín
# 20 Casa Mortero
# 21 Taberna Úbeda
# 22 Quimbaya
# 23 Trattoria Adriana
# 24 La Única
# 25 Commodore Madrid
# 26 La más croqueta
# 27 El Taller
# 28 Miss Sushi
# 29 La Terraza del Santo Domingo
# 30 MO de Movimiento
# 31 Coquetto Bar
# 32 Shukran City Ventas
# 33 Santa y Pura
# 34 Mune Madrid
# 35 Leña
# 36 Smoked Room
# 37 Barbecho
# 38 Diurno
# 39 Deessa
# 40 Villa Verbena
# 41 Citynizer Plaza
# 42 Barracuda MX
# 43 Aloha Poké
# 44 Tripea
# 45 Castelados
# 46 La Maruca
# 47 La MaMá Restaurante
# 48 Quinqué
# 49 Saddle
# 50 Bocanegra
# 51 Dani Brasserie
# 52 Bloom
# 53 La Venencia
# 54 Gran Vía 55
# 55 Bodega de La Ardosa
# 56 Casa Julio
# 57 Casa Camacho
# 58 Bodegas Ricla
# 59 Bar Santurce
# 60 Tablafina
# 61 Patio de Leones
# 62 Prístino
# 63 Neotaberna Santerra
# 64 Estimar
# 65 Ovillo
# 66 Restaurante  La Tajada
# 67 Restaurante Ponzano
# 68 Berlanga
# 69 Hermanos Vinagre
# 70 Válgame Dios
# 71 Maddock
# 72 Yugo the Bunker
# 73 Gofio by Cicero Canary
# 74 99 KŌ Sushi Bar
# 75 Restaurante Casa Pepe 1899
# 76 Landareak
# 77 La Huerta de Almería
# 78 B13
# 79 Chilling Cafe
# 80 Hakuna Matata Veggie
# 81 Cookaluzka
# 82 Bunny's Deli
# 83 Vega
# 84 Distrito Vegano Invernadero
# 85 Run Run Run
# 86 Occhiali
# 87 Colósimo
# 88 Aitatxu
# 89 Hong Kong 70
# 90 Zest
# 91 Salutteria
# 92 Indalo Tapas
# 93 Casa Lolea
# 94 Kippu
# 95 El Clásico
# 96 Xantar Astur
# 97 Alma Cocktails & Tapas
# 98 Pólvora
# 99 La Ventana de Flavia
# 100 La Casita de Sabino
# 101 Flora Fina
# 102 Da Luca Trattoria - Pizzeria
# 103 Caraba
# 104 Avocado Love
# 105 El Mirador del Olivar
# 106 Azotea Forus Barceló
# 107 Chigre
# 108 Hermanas Arce
# 109 Las Carboneras de Lu
# 110 Chido Castizo & Chingón
# 111 La Elegida
# 112 La Tasca del Retiro
# 113 Barra y Mantel
# 114 Marabú
# 115 La Cocina de Frente
# 116 Aüakt
# 117 El 5 de Tirso
# 118 Casa Julián de Tolosa (Ibiza)
# 119 El Jefe Traveling Food
# 120 La Carlota
# 121 La Veritá
# 122 Pieology
# 123 Mesteño Bar
# 124 Guillermina
# 125 Casa Ciriaco
# 126 El Amor Hermoso Bar
# 127 Casa Candi
# 128 Raimunda
# 129 Monsieur Sushita
# 130 Sottosopra
# 131 Pez Fuego
# 132 Ferretería by EGO
# 133 Doña Truhana
# 134 Noname Bar
# 135 Taberna Bandido
# 136 Doña Luz
# 137 Sinsombrero
# 138 Pic&Nic
# 139 Hake Mate
# 140 Giulietta
# 141 Sukaldean Bai Bokado
# 142 Lamucca (Plaza del Carmen)
# 143 La Bientirada
# 144 Iztac
# 145 Taberna El Gallocanta
# 146 Green Tea Food & Drinks
# 147 Ikigai
# 148 Enigmatium Room
# 149 La Madreña (Paseo de la Castellana)
# 150 Picalagartos Sky - Bar
# 151 Teje Maneje
# 152 Lambuzo (Retiro)
# 153 Yakiniku Rikyu
# 154 Yan Ken Pon
# 155 Shanghai mama (Cuzco)
# 156 Quispe
# 157 Les Mauvais Garçons
# 158 Hot Now
# 159 Dogma
# 160 Charrúa
# 161 Soma by Luke
# 162 Tasty Poke Bar
# 163 Como en Chile
# 164 San Wich
# 165 Restaurante Masterchef
# 166 Nudista
# 167 Arado. Grocery & Restaurant
# 168 Tres por Cuatro
# 169 Propaganda 12
# 170 Pomerania
# 171 Misska
# 172 Mawey Taco Bar
# 173 Lobo 8
# 174 La Cebichería de Trafalgar
# 175 Falafeleria
# 176 Cilindro
# 177 Botania
# 178 Alameda
# 179 De la Riva
# 180 Donzoko
# 181 Callao24
# 182 Astrolabius
# 183 El Buda Feliz 1974
# 184 Shinatora Ya
# 185 La Sal del Mentidero
# 186 Cascorro Bistrot
# 187 Grosso Napoletano (Santa Engracia)
# 188 Vagalume
# 189 Cortezo Yatai Market
# 190 El Greco
# 191 El Oso
# 192 La Catapa
# 193 La Bien Aparecida
# 194 99 Sushi Bar (Padre Damián)
# 195 Ruta 77 Palacio de Hielo
# 196 Volvoreta
# 197 Bump Green
# 198 Étimo
# 199 Ninja Ramen
# 200 La Castañal
# 201 La Boiga Taberna
# 202 Taberna Averías
# 203 Casa Baranda
# 204 Hortensio
# 205 Kanbun Taberna Oriental
# 206 Carl’s JR.
# 207 Alzahra
# 208 Pizzi & Dixie
# 209 Montmartre 1889
# 210 Kuoco 360º food
# 211 Corral de la Morería Restaurante Gastronómico
# 212 Candeli
# 213 El cielo de Urrechu
# 214 Ottica Restaurante
# 215 El Cucurucho del Mar
# 216 Morgana
# 217 Gula Gula
# 218 Clos Madrid
# 219 Paperboy Perrito Bar
# 220 Crêperie La Rue
# 221 La Casa Tomada
# 222 Bangalore Modern Indian Cuisine
# 223 Picoroco
# 224 Derzu Bar
# 225 Haches
# 226 Taramara
# 227 Casa Maravillas
# 228 Gustos Madrid Plaza Mayor
# 229 Tapas Gratis El Biombo (Hogar Extremeño)
# 230 Restaurante de Casa de Castilla La Mancha en Madrid
# 231 Restaurante Xiongzai
# 232 Cafetería Lily
# 233 Japanese Club
# 234 Gran Café de Madrid
# 235 Zielou
# 236 Pink Monkey
# 237 Borax
# 238 Havana Blues
# 239 Cuando salí de Cuba
# 240 La Taberna de Elia
# 241 MAD13
# 242 La Porcinería
# 243 Restaurante Gourmand
# 244 Foodtruck
# 245 Las chicas, los chicos y los maniquís
# 246 Taberna La Elisa
# 247 Condumios Taberna
# 248 Graciela
# 249 Taberna Artesana Verdejo
# 250 Vaca Nostra
# 251 La Gamella
# 252 Beker 6
# 253 [A]Brasa
# 254 Lux Madrid
# 255 The One
# 256 Membibre
# 257 Fellina
# 258 Santerra
# 259 KIP
# 260 Superchulo
# 261 La Pavía
# 262 Amargo Place to Be
# 263 Rocacho
# 264 Apartaco
# 265 Tiendas de Señorío
# 266 Rawcoco Green Bar Madrid
# 267 Aduana
# 268 Shuwa Shuwa
# 269 Doli
# 270 Puerta de Atocha
# 271 La Madreña (Calle del Bronce)
# 272 As Fontes
# 273 Al Punto
# 274 El Velázquez 17
# 275 NiMÚ Barquillo
# 276 Sargo. El arrecife de Madrid
# 277 The Mint Roof
# 278 Taberna Recreo
# 279 Sushita Café - Miguel Angel
# 280 Marcano
# 281 Levél Veggie Bistro
# 282 Enigmatium
# 283 Latasia Casa de Comidas
# 284 Casa Jaguar
# 285 Flores de Alcachofa
# 286 Fábula Buey & Champagne
# 287 Arima Basque Gastronomy
# 288 ¡Tu! Pasta
# 289 Soy Kitchen
# 290 Kappo
# 291 Inti de Oro
# 292 Ralph’s
# 293 Steak Burger (Gran Vía)
# 294 La Panera Rosa
# 295 Sugarcane
# 296 Sky Sushi & Ramen Bar
# 297 Ramen Shifu
# 298 Peyote San
# 299 Numa Pompilio
# 300 Narciso Brasserie
# 301 Media Ración
# 302 La Encarna Bistró Andaluz
# 303 Chow Chow
# 304 Casa Suecia
# 305 Canalla Bistró
# 306 Art & Sushi
# 307 Arallo Taberna
# 308 Al Socaire
# 309 La Encomienda
# 310 Dos Cielos Madrid
# 311 La Clave
# 312 Dans le noir?
# 313 Madame Sushita
# 314 Honest Greens
# 315 Esplore
# 316 Restaurante de la Residencia de Estudiantes
# 317 Surya
# 318 Cruz Blanca de Vallecas
# 319 Radio Rooftop
# 320 Alfredo’s barbacoa
# 321 El Escondite de Villanueva
# 322 Reineta
# 323 La Primera
# 324 Somos
# 325 Timesburg
# 326 A' kangas by Urrechu
# 327 El Flaco
# 328 Kirei Las Cortes
# 329 Kirei Barajas
# 330 Lubora
# 331 El Imparcial
# 332 Sidrería El Tigre
# 333 GastroVía 61
# 334 Ojalá
# 335 La Taurina
# 336 Los Arcos de Ponzano
# 337 Huerta de Carabaña
# 338 Robin Hood
# 339 Taberna El Tempranillo
# 340 El Invernadero
# 341 Gaytán
# 342 A´Barra
# 343 Makkila
# 344 NuBel
# 345 Pointer
# 346 Five Guys
# 347 Angelita Madrid
# 348 Vila Brasil
# 349 Sacha
# 350 Alcuzcuz de Alhuzema
# 351 Cannibal Raw Bar
# 352 La Taberna Murciana
# 353 Restaurante Mutis
# 354 Jimbo Smokehouse
# 355 Garbel Madrid
# 356 Casa Macareno
# 357 Taberna & Media
# 358 La Malaje
# 359 Carlos Oyarbide
# 360 Amazónico
# 361 La Bekada
# 362 El soportal
# 363 Bistronomika
# 364 Bibo Madrid
# 365 Puertalsol
# 366 Sal Negra
# 367 Jack Percoca
# 368 Fismuler
# 369 Cebo
# 370 López & López
# 371 YOUnique
# 372 Lamian by Soy Kitchen
# 373 Habanera
# 374 Bar El Pescador
# 375 Bar Alonso Cervecería Marisquería
# 376 Casa Emilio
# 377 Le Petit Comité
# 378 La Estación de los Porches
# 379 La Carmencita
# 380 Florida Park
# 381 El Pelícano
# 382 La Matritense
# 383 Bodegas Rivas
# 384 Sifón
# 385 KultO
# 386 Taberna Pedraza
# 387 La Excéntrica
# 388 Oven Mozarella Bar
# 389 Premiata Fornería Ballaró
# 390 Taberna Degusta
# 391 Ramen Kagura
# 392 Antigua Taquería
# 393 El Rincón Guay
# 394 Mad Brewing
# 395 Lakook Casa Árabe
# 396 Xareu
# 397 Vinos 11 Casa Dani
# 398 La Raquetista
# 399 Palo Cortado
# 400 Maestro Food & More
# 401 Restaurante Elkuru
# 402 As Jamonería
# 403 Mandarín
# 404 Royal Cantonés
# 405 Kzen
# 406 China Té
# 407 Casa Lafu
# 408 Asia Té
# 409 Perrachica
# 410 La Vaquería Montañesa
# 411 La Charca
# 412 Floren Domezáin
# 413 La Vanduca
# 414 Benares
# 415 Da Giuseppina
# 416 Marina Ventura
# 417 Lúa
# 418 Ronda 14
# 419 Swagat
# 420 Cachivache
# 421 Docamar
# 422 La Canica
# 423 Sal Gorda
# 424 Taberna Los Gallos
# 425 Filandón
# 426 Kilómetros de pizza
# 427 Kirikata
# 428 Restaurante Navaja
# 429 Naia Bistro
# 430 Lambuzo (Conchas)
# 431 La Platería
# 432 La Palma 60
# 433 Toque de Sal
# 434 Arzabal (Reina Sofía)
# 435 Restaurante Etíope Hanan
# 436 ElMandela
# 437 La berenjena
# 438 La Bobia
# 439 La Pescadería
# 440 El puchero de mi abuela
# 441 Los Chanquetes
# 442 O Pazo de Lugo
# 443 La Giralda IV
# 444 La Giralda II
# 445 Bocadillo de Jamón y Champán (Fernando VI)
# 446 El Perro y La Galleta
# 447 Askuabarra
# 448 Gochü
# 449 Izariya
# 450 Punto Básico
# 451 Gioia
# 452 La peseta de Doña Casilda
# 453 Hattori Hanzo
# 454 Tatel
# 455 Ático
# 456 La Tasquería
# 457 Bar Galleta
# 458 El Columpio
# 459 Marieta
# 460 La Verónica
# 461 La Lonja del Mar
# 462 La Gloria de Montera
# 463 Atelier Belge
# 464 Salón de Tapas Plaza Mayor
# 465 Taberna Corrientes
# 466 Taste Gallery
# 467 Metro Bistro (Plaza Mayor)
# 468 Salón Cascabel
# 469 Picsa
# 470 Mama Campo
# 471 Desencaja
# 472 Bacira
# 473 Celso y Manolo
# 474 Tándem
# 475 Alabaster
# 476 Ana La Santa
# 477 Montia
# 478 La Cabra
# 479 Bosco de Lobos
# 480 Vietnam Mekong
# 481 StreetXO
# 482 Café Colón Madrid
# 483 DSTAgE Concept
# 484  Yakitoro
# 485 Platea Madrid
# 486 La Buga del Lobo
# 487 Miyama
# 488 Nakeima Dumpling Bar
# 489 80º
# 490 Matute 12
# 491 Arzábal Retiro
# 492 Sala de Despiece
# 493 Triciclo
# 494 Taj
# 495 La Rebonita
# 496 María Bonita Taco Bar (Duque de Liria)
# 497 Bodega de Los Secretos
# 498 Arahy
# 499 Los Chuchis
# 500 Zombie Bar
# 501 Aroy Thai
# 502 Saporem
# 503 Juanyta Me Mata
# 504 El Mandil
# 505 La huerta de Tudela
# 506 Fuente de la Fama
# 507 Tacos Chapultepec
# 508 Du Liban
# 509 Taberna Casa Curro
# 510 Donde Mónica
# 511 M29
# 512 Materia Prima
# 513 Terramundi
# 514 Chirón
# 515 Mentidero de la Villa Restaurante
# 516 Costello Río
# 517 Thai Orchid
# 518 Restaurante Maru
# 519 Muñagorri
# 520 Taberna del Chato
# 521 Asgaya
# 522 El Patio de la Central (La Central de Callao)
# 523 Casa Mono
# 524 La Revoltosa
# 525 Támara Restaurante Lorenzo
# 526 El Tendido
# 527 Camino Food & Drinks
# 528 El Bund
# 529 Chifa
# 530 La Caña
# 531 Gobu Burger
# 532 Murillo Café
# 533 Tommy Mel's
# 534 La Castafiore
# 535 La Rue
# 536 Restaurante Vegetariano
# 537 El Económico. Soidemersol.
# 538 Hare Krishna
# 539 La Chula de Chamberí
# 540 Taberna Dehesa Santa María
# 541 Sagardi (Euskal Etxea)
# 542 Gourmet Bar
# 543 Le Petit Prince
# 544 La Plaza
# 545 El rey de tallarines
# 546 Trattoria Pinocchio (Sánchez Bustillo)
# 547 Naif
# 548 Couzapín
# 549 Lakasa
# 550 Pulpería Vilalúa
# 551 Sagar
# 552 Cañadío
# 553 Seoul
# 554 Han Gang
# 555 Korea
# 556 Dimibang
# 557 Dionisos
# 558 García de la Navarra
# 559 Surtopía
# 560 Mérimée
# 561 La Botillería
# 562 Cafetería-restaurante Colección Cibeles
# 563 Restaurante Terraza Palacio de Cibeles
# 564 La Sureña
# 565 La Casa del Pulpo
# 566 Minotauro
# 567 La Pulperia de Mila
# 568 Trattoria SantArcangelo
# 569 El Buey
# 570 Los Remos
# 571 Bar Amor
# 572 El Puerto de Cabreira
# 573 100 Montaditos
# 574 Gumbo
# 575 Yuè Lái (Joya Oriental)
# 576 Bolívar
# 577 Luzi Bombón
# 578 Soma
# 579 Rustika Tapas & Gin
# 580 Vi Cool
# 581 Magasand
# 582 Al Fanus
# 583 Mr. Kabab
# 584 La Escudilla
# 585 Nuria
# 586 Yerbabuena
# 587 Esfahan
# 588 St. James
# 589 La Antoñita
# 590 New York Burger
# 591 Aynaelda
# 592 El Boquerón
# 593 El Jardín del InterContinental
# 594 Cheese Bar de Poncelet
# 595 El Estragón Vegetariano
# 596 La Esquina de Chamberí
# 597 Asador Gerardo
# 598 TxaTei
# 599 Kulixka
# 600 Zen Market
# 601 Fuku
# 602 Ten con Ten
# 603 11 Nudos Terraza Nordés
# 604 La Jauría
# 605 El Qüenco de Pepa
# 606 Pittu
# 607 El Almirez
# 608 Orio
# 609 Enotaberna del León de Oro
# 610 Majaderitos Café
# 611 Nuevo Gerardo
# 612 La Tita Rivera
# 613 Taberna Moncloa
# 614 Pintxos Elcano
# 615 Gobolem (San Francisco)
# 616 Gobolem (Julián Romea)
# 617 José Luis (General Oráa)
# 618 Gran Sol
# 619 La Tapería del Prado
# 620 José Luis (San Francisco)
# 621 La Montadería
# 622 El Rincón de Jaén (Doctor Gómez Ulla)
# 623 La Taberna del Capitán Alatriste
# 624 El Rincón de Jaén (Ramón de la Cruz)
# 625 El Rincón de Jaén (Camilo José Cela)
# 626 Casa Jorge (Cartagena)
# 627 Cazorla (Castelló)
# 628 Casa Victor
# 629 Cazorla (Montesa)
# 630 Cazorla (Cipriano Sancho)
# 631 El Jamón del Abuelo
# 632 Fortuny Home Club
# 633 El Decano
# 634 El Buti Taberna
# 635 El Circo de las Tapas
# 636 Casa Fidel
# 637 The Cask
# 638 Yamate
# 639 Mashita
# 640 Oishii Sushi & Ramen
# 641 Ikura
# 642 Hanakura
# 643 Naomi
# 644 Lamucca de Pez (Carlos Cambronero)
# 645 Maldonado 14
# 646 Asturianos
# 647 La Pesquera
# 648 Gala (Espronceda)
# 649 Verdil
# 650 Colonial Norte
# 651 Ferreiro (Paseo de la Florida)
# 652 Lamucca (Prado)
# 653 Furusato
# 654 Cafetería HD
# 655 Treze
# 656 Buenas y Santas (Bolívar)
# 657 La Barra de Garcilaso
# 658 Goizeko Kabi
# 659 Los Rotos
# 660 Los Arroces de Segis
# 661 Samm
# 662 Bahiana
# 663 Restaurante Jota
# 664 Jota Batela
# 665 El Cocinillas
# 666 Casa Toribio
# 667 Taberna La Daniela
# 668 Las Reses
# 669 Toma Jamón (Vergara)
# 670 Salterius
# 671 Mesón Gallego II
# 672 Mesón Gallego I
# 673 Taberna La Lirio
# 674 Grazie Mille Kitchen Bar
# 675 Azotea del Círculo
# 676 Pontepez
# 677 Más Jamón
# 678 Casa Pedro
# 679 Ogrelo
# 680 Entre Suspiro y Suspiro
# 681 Taberna Agrado
# 682 Dibocca
# 683 BLoved
# 684 La Guisandera de Piñera
# 685 T.G.I Fridays
# 686 El Cenador de Salvador
# 687 Casa José
# 688 Coque
# 689 La Dichosa
# 690 El Respiro
# 691 El Rincón de Goya
# 692 Los Cedros
# 693 Bar Tomate
# 694 Cervecería Sol Mayor
# 695 Lateral
# 696 Casa María
# 697 Casa Rua
# 698 Bar Postas
# 699 El Brillante
# 700 Valle Del Tietar
# 701 Liana 1962
# 702 Magerit
# 703 La Campana
# 704 La ideal
# 705 Home Burger Bar (Silva)
# 706 Alma Café
# 707 Mesón del Cid
# 708 La Gran Tasca
# 709 Asador de Sacramenia
# 710 Asador el Molinón
# 711 Carlos Tartiere
# 712 Los Montes de Galicia
# 713 Los Arrieros
# 714 L'Abbraccio
# 715 Kupela
# 716 Asador Pelotari
# 717 Jai Alai
# 718 La Favorita
# 719 Horno de Juan
# 720 Teitu
# 721 Ferreiro (Aviador Zorita)
# 722 El Espigón
# 723 Taberna Las Botas
# 724 La Perejila
# 725 Delic
# 726 Vegaviana
# 727 La Biotika
# 728 Artemisa
# 729 Los Timbales
# 730 Casa Paulino
# 731 Tandoori Station
# 732 Mercato Ballaró
# 733 Rasputín
# 734 Come Prima
# 735 The James Joyce
# 736 Centro Riojano
# 737 El Ñeru
# 738 Algarabía
# 739 El Caldero
# 740 "Tres Peces" El Ventorrillo Murciano
# 741 Casa Ricardo
# 742 Restaurante Esteban
# 743 La Vera
# 744 Villa de Foz
# 745 Compostela
# 746 Casa Adriano
# 747 Ponteareas
# 748 Rías Bajas
# 749 Carta Marina
# 750 Casa Nemesio
# 751 Casa de Valencia
# 752 Can Punyetes (Señores de Luzón)
# 753 Los Galayos
# 754 El Senador
# 755 Venta la Hidalguía
# 756 Asador Real
# 757 El Tormo
# 758 El Escaldón
# 759 Mallorca en Madrid
# 760 Restaurante Uval
# 761 La Gabinoteca
# 762 Ramón Freixa Madrid
# 763 La Tavernetta
# 764 99 Sushi Bar (Hermosilla)
# 765 Taquería del Alamillo
# 766 Casa Marco
# 767 Ginger
# 768 Krachai
# 769 Vesuvio
# 770 Olivia te cuida
# 771 Fass
# 772 Caripén
# 773 De Maria (Correo)
# 774 De María (Gran Vía)
# 775 De María (Hortaleza)
# 776 De María (Preciados)
# 777 De María (Félix Boix)
# 778 Beef Place
# 779 Entrevinos
# 780 La Cocina de María Luisa
# 781 Don Giovanni
# 782 La Montería
# 783 Puerto de Lagasca
# 784 Naveira do mar
# 785 Mestizo
# 786 Restaurante Villa Magna
# 787 La Buganvilla
# 788 El Mirador del Thyssen
# 789 Las Cuevas de Luis Candelas
# 790 Summa To Go
# 791 Nipon Taro
# 792 Ichiban
# 793 Ayala Japón
# 794 Inari
# 795 19 Sushi Bar
# 796 Kokoro
# 797 Ginza
# 798 Mikado
# 799 Taberna Alipio Ramos
# 800 La Tasca Suprema
# 801 99 Sushi Bar (Ponzano)
# 802 La Copla
# 803 Soy
# 804 La Ancha (Príncipe de Vergara)
# 805 Viavélez
# 806 La Buena Vida
# 807 Nicomedes
# 808 La Parra
# 809 El Café de la Ópera
# 810 Casa Narcisa
# 811 Bodegas Alfaro
# 812 Bodegas Rosell
# 813 La casa de las torrijas
# 814 Tienda de vinos (El comunista)
# 815 Stop Madrid
# 816 Tse Yang Villa Magna
# 817 La Penela
# 818 Viva Burger
# 819 El Cisne Azul
# 820 Janatomo
# 821 Albahía
# 822 Conache
# 823 Gaudium
# 824 El Sur
# 825 Malacatín
# 826 Casa Paco
# 827 Moncalvillo
# 828 Public
# 829 Clarita
# 830 Casa Perico
# 831 La Panza es Primero
# 832 La Mordida de Segovia
# 833 Sí Señor
# 834 Tepic
# 835 Estado Puro
# 836 Cervecería Plaza Mayor 2
# 837 La Esquina
# 838 Taberna Almería
# 839 Viejo Madrid
# 840 Restaurante UNO by Meliá Madrid Princesa
# 841 Ramses
# 842 Mercado de la Reina
# 843 Con Dos Fogones
# 844 El Fogón de Trifón
# 845 Cervecería Alemana
# 846 El Anciano Rey de los Vinos
# 847 El Cantábrico
# 848 La musa de Espronceda
# 849 Casa Manolo
# 850 Los Caracoles
# 851 Cangrejero
# 852 La Musa Latina
# 853 La Colonial de Goya
# 854 Maceiras (Huertas)
# 855 La cruzada
# 856 Taberneros
# 857 Las Bravas (Pje Matheu)
# 858 Matritum
# 859 Cervecería Cervantes
# 860 Maceiras (Jesús)
# 861 Huevos de Lucio
# 862 Taberna Ángel Sierra
# 863 Juana la Loca
# 864 Vinoteca Barbechera
# 865 Taberna Los Gatos
# 866 Baco y Beto
# 867 Las Bravas (Álvarez Gato)
# 868 Melo´s
# 869 Lamiak
# 870 La Tape
# 871 La Musa (Manuela Malasaña)
# 872 La Casa del Abuelo
# 873 La Camocha
# 874 La Castela
# 875 Mesón Cinco Jotas (Serrano)
# 876 Mesón Cinco Jotas  (Puigcerdá)
# 877 Jurucha
# 878 Mesón Cinco Jotas (Padre Damián)
# 879 José Luis (Pº de la Habana)
# 880  José Luis (Rafael Salgado)
# 881 José Luis (Serrano)
# 882 Taberna Cuenllas
# 883 Taberna de la Dolores
# 884 Estay
# 885 El Quinto Vino
# 886 Fide
# 887 Le Petit Hándicap
# 888 Vinos y tapas Pardiñas 25
# 889 Hevia
# 890 O´Caldiño
# 891 Sylkar
# 892 Sagaretxe
# 893 El Doble
# 894 Casa Revuelta
# 895 Restaurante Rafa
# 896 Taberna del Puerto
# 897 Casa Lucas
# 898 El Espejo
# 899 Taberna Almendro 13
# 900 Cervecería Santa Bárbara
# 901 Taberna Rayuela
# 902 De Partida
# 903 La Máquina de Chamberí
# 904 Rubaiyat  Madrid
# 905 El Paraguas
# 906 Puerta 57
# 907 Samarkanda
# 908 The Library Restaurant ( Santo Mauro, a Luxury Collection Hotel)
# 909 La Masía de José Luis
# 910 La Barraca
# 911 Asador de Aranda
# 912 Zerain
# 913 Zalacaín
# 914 Zara
# 915 Asia Gallery (The Westin Palace)
# 916 Asador Donostiarra
# 917 Horcher
# 918 Lhardy
# 919 Artys Madrid
# 920 Più di Prima
# 921 Casa Mingo
# 922 Casa Lucio
# 923 Casa Hortensia
# 924 Casa d'a Troya
# 925 Casa Carola
# 926 El Landó
# 927 Kabuki
# 928 Casa Julián de Tolosa (Cava Baja)
# 929 El Jardín de Orfila
# 930 Mesón Txistu
# 931 El Chaflán
# 932 Taberna del Alabardero
# 933 Bazaar
# 934 La Ancha (Zorrilla)
# 935 Al-Mounia
# 936 Restaurante Café de Oriente Museo del Traje
# 937 Goizeko Wellington
# 938 La Finca de Susana
# 939 Ecocentro
# 940 East 47
# 941 Casa Benigna
# 942 Hyragana (Vincci Soho)
# 943 Las Infantas
# 944 La Tasquita de Enfrente
# 945 Paco Roncero Restaurante
# 946 Viridiana
# 947 Café Saigón
# 948 Viuda de Vacas
# 949 Botín
# 950 La Bola
# 951 El Pescador
# 952 Mercado de Espronceda
# 953 Restaurante Las Cortes
# 954 La Hoja
# 955 Arce
# 956 Las Tortillas de Gabino
# 957 Gaztelupe
# 958 Taberna Antonio Sánchez
# 959 La Ópera de Madrid
# 960 Posada de la Villa
# 961 O'Pazo
# 962 Ricardo Sanz Wellington
# 963 DiverXO
# 964 Edelweiss
# 965 Casa Labra
# 966 Casa Alberto
# 967 Café de Oriente
# 968 Dantxari
# 969 Laredo
# 970 La Esquina del Real
# 971 La Rotonda (The Westin Palace)
# 972 Prada a Tope
# 973 Ox's
# 974 El Gran Barril
# 975 La Paloma
# 976 La Manduca de Azagra
# 977 Manolo
# 978 Real Café Bernabéu
# 979 Antigua Embajada (Hotel Palacio San Martín)
# 980 Café Varela Restaurante (Hotel Preciados)
# 981 Oliveros
# 982 El Rincón de Esteban
# 983 Allard Madrid
# 984 La Trainera
# 985 Paradís Madrid
# Introduzca el restaurante por su número correspondiente: 22
# Nombre:
# Quimbaya
# E-mail:
# reservas@quimbayarestaurant.com
# Teléfono:
# (+34) 91 240 18 96
# Descripción:
# El chef colombiano Edwin Rodríguez lidera el primer restaurante de cocina colombiana de autor en Madrid, reconocido con una estrella Michelin en la edición 2022 de la prestigiosa guía turística. Desde el barrio de Chamberí, Rodríguez presenta una propuesta inspirada en los sabores colombianos, bajo la interpretación contemporánea, creativa y personal del chef, que también ha sido galardonada con un Sol Repsol.La cocina de Quimbaya es su alma, por eso está abierta y se puede observar desde la sala el trabajo del chef y su equipo.  Quimbaya propone un Menú Degustación a través del cual se puede recorrer las distintas zonas gastronómicas de Colombia, desde el Caribe al Amazonas, pasando por el Pacífico, los Andes y la Orinoquía, a través de historias creadas por el chef y reflejadas en sus platos, además de contar con la posiblidad de comer a la carta. Su oferta se completa con una gran variedad de cócteles de la casa, así como con una interesante selección de rones, aguardientes y ginebras colombianas, y, por supuesto, café 100% Colombia y aromática de frutas.En la trayectoria profesional de Edwin Rodríguez destacan sus casi diez años de trabajo con el chef Pepe Rodríguez en el restaurante El Bohío (1 Estrella Michelín). Desde 2013, Rodríguez ha representado a la cocina colombiana en diferentes eventos privados y públicos realizados por ProColombia y las Embajadas de Colombia en Seúl, Madrid y Londres como son FITUR, MADRID FUSIÓN, ARCO, WTM, CUMBRE ALIANZA DEL PACÍFICO, entre otros.
# Página web:
# https://www.esmadrid.com/restaurantes/quimbaya
# Localizacion:
# de Zurbano, 63.Madrid, 28010
# Tipo de cocina:
# Internacional : Colombiana
# De autor
# Horario:  Servicio de Carta:  Mar – Vier: 13:30 – 16:30 h / 20:00 – 24:00 hMenú Degustación (sábados, domingos y festivos sólo menú degustación):Mar – Sáb: 13:30 – 16:30 h/ 20:00 – 24:00 hDomingos: 13:30- 16:30 hServicio de Barra:Mar – Sáb: 13:30 – 16:30 h / 20:00 – 24:00 hDomingos: 13:30 – 16:30 h
# ¿Mostrar foto? S/N: N
# ¿Repetir la búsqueda? S/N: N

# %%
img_src = 'https://estaticos.esmadrid.com/cdn/farfuture/OdE0pLpf9itK-izdD2Qz8DzXCB2y9S2Prl8AYfNeTiA/mtime:1664200548/sites/default/files/recursosturisticos/restaurantes/joel_robuchon_4.jpg'
from skimage import io
image = io.imread(img_src)
io.imshow(image)
io.show()

# %% [markdown]
# Despues de mostrar la información y las imagenes del restaurante elegido se le preguntará si desea volver a ver el listado de restaurantes para ver otro o bien desea finalizar.
#
# Observar:
#   * Algunas etiquetas podrían estar vacías o no aparecer. En estos casos, simplemente se mostrará vacío o con la palabra "Desconocido".
#   * Hay que limpiar el texto de la descripción eliminando los símbolos especiales del tipo tales como "&lt;/p&gt;&lt;p&gt;" que aparecen en el mismo.
#
# Por ejemplo si el usuario hubiera elegido el restaurante "Hasaku Nikkei" debería mostrarse por pantalla:
#
# __Nombre del restaurante:__
#
# Hasaku Nikkei
#
# __Descripción:__
# La apuesta culinaria por la cocina nikkei del chef peruano Jhosef Arias se traduce en este restaurante situado en el barrio de Las Tablas. De estética minimalista, en él se puede disfrutar de la mezcla de dos culturas gastronómicas: la peruana y la japonesa, una de las muestras más notorias de la fusión cultural a través de la cocina.El nombre Hasaku proviene del japonés y hace referencia a una naranja agria e híbrida, que, en este caso, tiene relación con la lima y los cítricos, hilo conductor de la cocina peruana. Con este nombre se busca ofrecer una especie de reconocimiento y agradecimiento a la enorme influencia que supuso la inmigración y la cocina japonesa en la gastronomía peruana.Hasaku comenzó siendo un proyecto virtual llevado a cabo durante el cierre de los restaurantes por la pandemia provocada por la COVID-19, al que el chef dedicó muchas horas de experimentación.En su carta se pueden encontrar platos excepcionales que se pueden disfrutar tanto en el local como en casa gracias a su servicio de envio a domicilio. No disponen de menú diario pero sí de dos menús degustación con los platos más destacados de su propuesta gastronomíca.Arias se ha convertido en un referente de la gastronomía peruana en Madrid, donde cuenta con otros restaurantes: Piscomar, en Lavapiés; Humo, en Puente de Vallecas; Callao24, en Arturo Soria; y su más reciente creación,ADN Origen Perú, en la calle Mayor, junto al Mercado de San Miguel. En todos ellos ensalza distintos aspectos de la gastronomía de su tierra. No en vano forma parte de los 50 chefs del movimiento Generación con Causa, creado en Perú para promover la cocina peruana en el mundo, a través de la cuarta generación de cocineros, avalados por el reconocido chef peruano Gastón Acurio.
#
# __Página web:__
#
# https://www.esmadrid.com/restaurantes/hasaku-nikkei
#
# __Email:__
#
# Desconocido
#
# __Teléfono:__
#
# (+34) 91 210 54 43
#
# __Localización:__
#
# María Tubau, 17. Madrid 28050
#
# __Horario:__
#
# Mar; Sáb: 13:00-16:00h/20:00- 01:00 ; Domingo: 13:00-16:00 h
#
# __Tipo de cocina:__
#
# Internacional: Fusión, Internacional, Japonesa, Peruana

# %% [markdown]
# __Ejercicio 2 [2.5 puntos]__
#
# Este ejercicio se pide crear un buscador sobre la información recuperada, de forma que el usuario podrá buscar restaurantes por el tipo de cocina ofrecida en un restaurante. Para ello se le mostrará un listado con los diferentes tipos de cocina que se han encontrado en el fichero, y el usuario elegirá un tipo de cocina.  Como resultado debería mostrarse un listado de todas los restaurantes que cumplen las condiciones impuestas por el usuario. Se mostrará los nombres de los restaurantes. A continuación el usuario elegirá uno de los restaurantes y entonces se le mostrará  la misma información del restaurante que en el ejercicio 1.
#
# Después de mostrarle la información, se le volverá a preguntar si quiere seguir buscando. Entre las opciones del menú deberá existir una que sea para finalizar la búsqueda.

# %%
# Construye un diccionario cuyas claves son las categorías y los valores son listas con las subcategorías (en caso de haberlas)
def tipos_de_cocina():
    tipos_cocina = dict()

    for nodo in arbol.findall("service"):
        categorias = nodo.find("extradata/categorias")
        for cat in categorias:
            cat_name = cat.findall("item")[1].text
            if cat_name not in tipos_cocina:
                tipos_cocina[cat_name] = list()
            try:
                for subcat in cat.find("subcategorias"):
                    subcat_name = subcat.findall("item")[1].text
                    if subcat_name not in tipos_cocina[cat_name]:
                        tipos_cocina[cat_name].append(subcat_name)
            except TypeError:
                pass
    return tipos_cocina

def menu_cocina(tipos_cocina):
    for i,cat in enumerate(tipos_cocina.keys()):
        print(f"{i+1} - {cat}")
        subcats = list(tipos_cocina[cat])
        for j,sub in enumerate(subcats):
            print(f"    {i+1}.{j+1} - {sub}")

    return input("Seleccione un tipo de cocina:")

# Construye una lista con las tuplas (nombre, id) de los restaurantes que pertenecen a una determinada categoría o subcategoría
def lista_restaurantes(categoria):
    restaurantes = list(tuple())
    for nodo in arbol.findall("service"):
        categorias = nodo.find("extradata/categorias")
        # Busca en categorías y sino en subcategorías
        for cat in categorias:
            if cat.findall("item")[1].text == categoria:
                restaurantes.append((limpiar(nodo.find("basicData/name").text), nodo.attrib["id"]))
                break
            else:
                try:
                    for subcat in cat.find("subcategorias"):
                        if subcat.findall("item")[1].text == categoria:
                            restaurantes.append((limpiar(nodo.find("basicData/name").text), nodo.attrib["id"]))
                except TypeError:
                    pass

    return restaurantes

def menu_restaurantes(restaurantes):
    for i,res in enumerate(restaurantes):
        print(f"{i+1}: {res[0]}")
    return int(input("Seleccione un restaurante:")) - 1

def buscar_categoria(tipos_cocina, opcion):
    keys = list(tipos_cocina)
    # Si se elige una subcategoría se accede a la lista de subcategorías a través del número de detrás del punto
    if "." in opcion:
        (cat,subcat) = opcion.split(".")
        return tipos_cocina[keys[int(cat) - 1]][int(subcat) - 1]
    else:
        return keys[int(opcion)]

def buscar_restaurante(id):
    res = None
    for nodo in arbol.findall("service"):
        if nodo.attrib["id"] == id:
            res = nodo
            
    return res


tipos_cocina = tipos_de_cocina()

seguir = True
while seguir:
    opcion = menu_cocina(tipos_cocina)

    categoria = buscar_categoria(tipos_cocina, opcion)

    print(f"\nRestaurantes de cocina {categoria}:")
    restaurantes = lista_restaurantes(categoria)
    opcion = menu_restaurantes(restaurantes)

    restaurante = buscar_restaurante(restaurantes[opcion][1])
    mostrar_restaurante(restaurante)

    seguir = input("¿Desea seguir buscando?(s/n): ") == "s"
# Out:
# 1 - Internacional
#     1.1 - Fusión
#     1.2 - Internacional
#     1.3 - Japonesa
#     1.4 - Peruana
#     1.5 - Cubana
#     1.6 - Asiática
#     1.7 - China
#     1.8 - Tailandesa
#     1.9 - Mexicana
#     1.10 - Italiana
#     1.11 - Colombiana
#     1.12 - Libanesa
#     1.13 - Hawaiana
#     1.14 - Latinoamericana
#     1.15 - Norteamericana
#     1.16 - Coreana
#     1.17 - Francesa
#     1.18 - Chilena
#     1.19 - Israelí
#     1.20 - Vietnamita
#     1.21 - Árabe
#     1.22 - Venezolana
#     1.23 - Hindú
#     1.24 - Belga
#     1.25 - Portuguesa
#     1.26 - Argentina
#     1.27 - Brasileña
#     1.28 - Marroqui
#     1.29 - Europea
#     1.30 - Africana
#     1.31 - Caribeña
#     1.32 - Griega
#     1.33 - Siria
#     1.34 - Iraní
#     1.35 - Persa
#     1.36 - Rusa
#     1.37 - Irlandesa
#     1.38 - Alemana
# 2 - De autor
# 3 - Tapas
#     3.1 - Tapas
#     3.2 - Gastrobares
# 4 - Española
#     4.1 - Mediterránea
#     4.2 - Tradicional
#     4.3 - Marisquería
#     4.4 - Española
#     4.5 - Madrileña
#     4.6 - Casera
#     4.7 - Tradicional renovada
#     4.8 - Gallega
#     4.9 - De temporada
#     4.10 - Asador / Parrilla
#     4.11 - Arrocería
#     4.12 - Cántabra
#     4.13 - Andaluza
#     4.14 - Canaria
#     4.15 - Asturiana
#     4.16 - Vasco-Navarra
#     4.17 - Vasca
#     4.18 - Castellano-Manchega
#     4.19 - Castellana
#     4.20 - Castellano-Leonesa
#     4.21 - Murciana
#     4.22 - Navarra
#     4.23 - Valenciana
#     4.24 - Catalana
#     4.25 - Riojana
#     4.26 - Extremeña
#     4.27 - Balear
# 5 - Multiespacio
# 6 - Tabernas
# 7 - Especiales
#     7.1 - Halal
#     7.2 - Otros
#     7.3 - Kosher
# 8 - Bares
# 9 - Vegano
# 10 - Vegetariano
# Seleccione un tipo de cocina:4.25
#
# Restaurantes de cocina Riojana:
# 1: Centro Riojano
# 2: Algarabía
# Seleccione un restaurante:2
# Nombre:
# Algarabía
# E-mail:
# algarabia.muro@gmail.com
# Teléfono:
# (+34) 91 140 76 52
# Descripción:
# Se trata de un acogedor local, con una cocina riojana de calidad. Con productos de temporada de la más alta calidad, ofrece especialidades como los pimientos o el bacalao.Un restaurante familiar y acogedor dirigido por dos hermanas. Un lugar donde sentirse como en casa gracias a la atención de Pilar y la cocina de Isabel. De esta manera, los comensales pueden disfrutar de sus especialidades como los pimientos y el bacalao a la riojana, el pisto riojano con arroz o el chumarro con cebolla confitada. Algarabía se encuentra en la calle Unión, en plena zona centro, muy cerca de la Puerta del Sol, y es recomendable reservar mesa con antelación.
# Página web:
# https://www.esmadrid.com/restaurantes/algarabia
# Localizacion:
# Unión, 8.Madrid, 28013
# Tipo de cocina:
# Tapas : Tapas
# Española : Riojana
# Horario:  Lunes: 14:00 - 17:00 h. / 21:00 - 23:15 h.Mar - Sáb: 21:00 - 23:30 h.Domingos cerrado
# ¿Desea seguir buscando?(s/n): s
# 1 - Internacional
#     1.1 - Fusión
#     1.2 - Internacional
#     1.3 - Japonesa
#     1.4 - Peruana
#     1.5 - Cubana
#     1.6 - Asiática
#     1.7 - China
#     1.8 - Tailandesa
#     1.9 - Mexicana
#     1.10 - Italiana
#     1.11 - Colombiana
#     1.12 - Libanesa
#     1.13 - Hawaiana
#     1.14 - Latinoamericana
#     1.15 - Norteamericana
#     1.16 - Coreana
#     1.17 - Francesa
#     1.18 - Chilena
#     1.19 - Israelí
#     1.20 - Vietnamita
#     1.21 - Árabe
#     1.22 - Venezolana
#     1.23 - Hindú
#     1.24 - Belga
#     1.25 - Portuguesa
#     1.26 - Argentina
#     1.27 - Brasileña
#     1.28 - Marroqui
#     1.29 - Europea
#     1.30 - Africana
#     1.31 - Caribeña
#     1.32 - Griega
#     1.33 - Siria
#     1.34 - Iraní
#     1.35 - Persa
#     1.36 - Rusa
#     1.37 - Irlandesa
#     1.38 - Alemana
# 2 - De autor
# 3 - Tapas
#     3.1 - Tapas
#     3.2 - Gastrobares
# 4 - Española
#     4.1 - Mediterránea
#     4.2 - Tradicional
#     4.3 - Marisquería
#     4.4 - Española
#     4.5 - Madrileña
#     4.6 - Casera
#     4.7 - Tradicional renovada
#     4.8 - Gallega
#     4.9 - De temporada
#     4.10 - Asador / Parrilla
#     4.11 - Arrocería
#     4.12 - Cántabra
#     4.13 - Andaluza
#     4.14 - Canaria
#     4.15 - Asturiana
#     4.16 - Vasco-Navarra
#     4.17 - Vasca
#     4.18 - Castellano-Manchega
#     4.19 - Castellana
#     4.20 - Castellano-Leonesa
#     4.21 - Murciana
#     4.22 - Navarra
#     4.23 - Valenciana
#     4.24 - Catalana
#     4.25 - Riojana
#     4.26 - Extremeña
#     4.27 - Balear
# 5 - Multiespacio
# 6 - Tabernas
# 7 - Especiales
#     7.1 - Halal
#     7.2 - Otros
#     7.3 - Kosher
# 8 - Bares
# 9 - Vegano
# 10 - Vegetariano
# Seleccione un tipo de cocina:1.9
#
# Restaurantes de cocina Mexicana:
# 1: Bakan
# 2: La Única
# 3: Barracuda MX
# 4: Chido Castizo & Chingón
# 5: Iztac
# 6: Mawey Taco Bar
# 7: Ottica Restaurante
# 8: Pink Monkey
# 9: Lux Madrid
# 10: Peyote San
# 11: Antigua Taquería
# 12: Salón Cascabel
# 13: Matute 12
# 14: La Rebonita
# 15: María Bonita Taco Bar (Duque de Liria)
# 16: Tacos Chapultepec
# 17: Entre Suspiro y Suspiro
# 18: Taquería del Alamillo
# 19: Mestizo
# 20: La Panza es Primero
# 21: La Mordida de Segovia
# 22: Sí Señor
# 23: Tepic
# Seleccione un restaurante:5
# Nombre:
# Iztac
# E-mail:
# Desconocido
# Teléfono:
# (+34) 910 090 235
# Descripción:
# Situado en el mismo lugar en el que abrió el que fue el primer restaurante mexicano de Madrid, México lindo, en la Plaza de la República de Ecuador, Iztac ofrece una propuesta gastronómica diseñada por el chef Nacho Oropeza, que descubre al comensal los sabores más auténticos de una cocina que fue la primera en ser nombrada patrimonio invaluable de la humanidad por la UNESCO.El local cuenta con una zona de bar impactante, donde las botellas de la cerveza más famosa mexicana, Corona, tienen un papel protagonista. La cocina, de estilo vanguardista, está abierta al comedor, donde destacan los tonos neutros, la presencia de la luz y los cuadros de Gabriel Moreno.La carta recorre los 32 estados mexicanos a través de platos que recogen todas las opciones culinarias del país. La oferta gastronómica se completa con una amplia coctelería.
# Página web:
# https://www.esmadrid.com/restaurantes/iztac
# Localizacion:
# de la República de Ecuador, 4.Madrid, 28016
# Tipo de cocina:
# Internacional : Mexicana
# Horario:  Mar – sáb: 13:30 -16:30 h/ 21:00 – 24:00 hDomingos: 13:30 – 16:30 h
# ¿Desea seguir buscando?(s/n): n

# %% [markdown]
#  __Ejercicio 3[2.5 puntos]__
#
# Este ejercicio se pide crear un buscador de restaurantes por cercania a una calle indicada por el usuario. Para ello se usará la librería GeoPy que se usó en la práctica 2 y la información de latitud y longitud que aparece en el archivo xml de cada uno de los restaurantes. Se le preguntará al usuario que introduzca por teclado el nombre de la información de la calle, y la distancia en kilómetros de cercania.
#
# Como resultado debería mostrarse un listado de todas los restaurantes que cumplen las condiciones impuestas por el usuario. Se mostrará los nombres de los restaurantes. A continuación el usuario elegirá uno de los restaurantes y entonces se le mostrará  la misma información del restaurante que en el ejercicio 1.  En caso de no existir un restaurante con las condiciones dadas, se mostrará un mensaje informativo.
#
#  Después de mostrarle la información, se le volverá a preguntar si quiere seguir buscando. Entre las opciones del menú deberá existir una que sea para finalizar la búsqueda.

# %%
from math import radians, cos, sin, asin, sqrt

def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    # Radius of earth in kilometers is 6371
    km = 6371* c
    return km

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="Restaurantes cercnaos")

def dist(restaurante, location):
    
    try:
        lat_res = float(restaurante.find("geoData").find("latitude").text)
        lon_res = float(restaurante.find("geoData").find("longitude").text)
  
        return haversine(lat_res, lon_res, location.latitude, location.longitude)
    
    except TypeError:
        print("aaaaaaa")
        return None

restaurantes = arbol.findall("service")
while True:
    
    calle = input("Introduce una calle: ")
    max_dist = float(input("Introduce la distancia máxima en km: "))
    location = geolocator.geocode(calle + ", Madrid, España", addressdetails=True)
    
    dist_restaurantes = [(ind, dist(rest, location)) for ind, rest in enumerate(restaurantes)]
    rest_proximos = [x for x in dist_restaurantes if x[1] <= max_dist]
    rest_proximos.sort(key=lambda x: x[1])
    print("-------------------------------------------------")
    
    if len(rest_proximos) > 0:
                   
        for ind, dist_res in enumerate(rest_proximos):
            
            id_res = dist_res[0]
            km = dist_res[1]
            #print(id_res)            
            print(f"{ind + 1}: {limpiar(restaurantes[id_res].find('basicData').find('name').text)} ({round(km, 2)}km)")
            
        opcion = int(input("\nEscoja una opción: "))
        # TODO: aplicar función del ej1 a restaurantes[opcion] para mostrar información del
        # restaurante ecogido.
        mostrar_restaurante(restaurantes[rest_proximos[opcion - 1][0]])
            
    else:
        print("No hay restaurantes cercanos")
        
    if input("\nQuiere realizar otra búsqueda (si/no): ").lower() == "no":
        break
# Out:
# Introduce una calle: embajadores
# Introduce la distancia máxima en km: 1
# -------------------------------------------------
# 1: Melo´s (0.15km)
# 2: López & López  (0.18km)
# 3: Antigua Taquería (0.2km)
# 4: Albahía (0.27km)
# 5: Los Chuchis (0.3km)
# 6: Taberna Antonio Sánchez (0.3km)
# 7: La Rebonita (0.3km)
# 8: El Rincón Guay (0.31km)
# 9: Bodegas Alfaro (0.32km)
# 10: El Boquerón (0.34km)
# 11: "Tres Peces" El Ventorrillo Murciano (0.34km)
# 12: El 5 de Tirso (0.34km)
# 13: La Malaje (0.36km)
# 14: El Económico. Soidemersol. (0.36km)
# 15: El Sur (0.37km)
# 16: La Encomienda (0.4km)
# 17: Cortezo Yatai Market (0.4km)
# 18: La Buga del Lobo (0.41km)
# 19: Citynizer Plaza (0.42km)
# 20: Distrito Vegano Invernadero (0.42km)
# 21: Las chicas, los chicos y los maniquís (0.44km)
# 22: El Imparcial (0.45km)
# 23: La Vera (0.45km)
# 24: Ferretería by EGO (0.47km)
# 25: Restaurante Casa Pepe 1899 (0.48km)
# 26: As Jamonería (0.51km)
# 27: Matute 12 (0.51km)
# 28: Yan Ken Pon (0.52km)
# 29: Ginger (0.52km)
# 30: Vi Cool (0.52km)
# 31: Maestro Food & More (0.52km)
# 32: La musa de Espronceda (0.53km)
# 33: Casa Alberto (0.54km)
# 34: Los Chanquetes (0.54km)
# 35: Lateral  (0.54km)
# 36: El Caldero (0.55km)
# 37: Ana La Santa (0.55km)
# 38: Radio Rooftop (0.55km)
# 39: Fuente de la Fama (0.56km)
# 40: Cascorro Bistrot (0.57km)
# 41: Alma Café (0.57km)
# 42: Taberna del Chato (0.57km)
# 43: Malacatín (0.57km)
# 44: Cervecería Alemana  (0.58km)
# 45: Bar Santurce (0.58km)
# 46: Santa y Pura (0.59km)
# 47: La Bobia (0.6km)
# 48: Come Prima (0.6km)
# 49: La Huerta de Almería (0.6km)
# 50: Inclán Brutal Bar (0.6km)
# 51: Oliveros (0.6km)
# 52: Miss Sushi (0.61km)
# 53: Las Bravas (Álvarez Gato) (0.61km)
# 54: Vinoteca Barbechera  (0.61km)
# 55: La Biotika (0.62km)
# 56: Reineta (0.64km)
# 57: Restaurante Las Cortes (0.65km)
# 58: Gofio by Cicero Canary (0.66km)
# 59: Restaurante de Casa de Castilla La Mancha en Madrid   (0.67km)
# 60: La casa de las torrijas (0.67km)
# 61: La Casa del Abuelo  (0.67km)
# 62: Triciclo (0.68km)
# 63: La Negra Tomasa (0.68km)
# 64: Majaderitos Café (0.69km)
# 65: Lamucca (Prado) (0.71km)
# 66: La berenjena (0.71km)
# 67: Metro Bistro (Plaza Mayor) (0.71km)
# 68: O Pazo de Lugo (0.72km)
# 69: La más croqueta (0.72km)
# 70: Casa María  (0.72km)
# 71: Las Bravas (Pje Matheu) (0.72km)
# 72: El Clásico (0.72km)
# 73: Han Gang (0.73km)
# 74: Salón de Tapas Plaza Mayor (0.73km)
# 75: Enigmatium Room (0.73km)
# 76: Zerain (0.73km)
# 77: La Taberna del Capitán Alatriste (0.73km)
# 78: La huerta de Tudela (0.73km)
# 79: Prada a Tope (0.73km)
# 80: La Finca de Susana (0.74km)
# 81: Los Galayos (0.74km)
# 82: Hyragana (Vincci Soho) (0.74km)
# 83: Marina Ventura  (0.75km)
# 84: La ideal (0.75km)
# 85: La Campana (0.75km)
# 86: Lobo 8 (0.75km)
# 87: La Venencia (0.76km)
# 88: Posada de la Villa (0.76km)
# 89: Taberna La Elisa (0.76km)
# 90: Liana 1962 (0.77km)
# 91: Casa Revuelta (0.77km)
# 92: De Maria (Correo) (0.77km)
# 93: La Antoñita (0.77km)
# 94: Lhardy (0.77km)
# 95: Saporem (0.77km)
# 96: Cervecería Plaza Mayor 2 (0.78km)
# 97: Botín (0.78km)
# 98: Casa Julián de Tolosa (Cava Baja) (0.78km)
# 99: Cervecería Sol Mayor (0.78km)
# 100: Bar Postas (0.78km)
# 101: Enotaberna del León de Oro (0.79km)
# 102: Matritum (0.79km)
# 103: El soportal (0.79km)
# 104: La Taurina (0.79km)
# 105: Donzoko (0.79km)
# 106: Taberna Casa Curro (0.8km)
# 107: Tándem (0.8km)
# 108: La Perejila (0.8km)
# 109: Taberna La Daniela  (0.8km)
# 110: Casa Victor   (0.8km)
# 111: Taberna Corrientes (0.81km)
# 112: Bodegas Ricla (0.81km)
# 113: Casa Paco (0.82km)
# 114: Las Cuevas de Luis Candelas (0.82km)
# 115: NuBel (0.82km)
# 116: Hong Kong 70 (0.82km)
# 117: Maceiras (Huertas) (0.82km)
# 118: Terramundi (0.82km)
# 119: Huevos de Lucio (0.83km)
# 120: Casa Lucas (0.83km)
# 121: Zen Noodle Bar (0.83km)
# 122: Tommy Mel's  (0.83km)
# 123: Cebo  (0.84km)
# 124: Maceiras (Jesús) (0.84km)
# 125: Viejo Madrid (0.84km)
# 126: Puertalsol (0.84km)
# 127: Vinoteca Moratín (0.84km)
# 128: Gustos Madrid Plaza Mayor (0.85km)
# 129: Mad Gourmets (0.85km)
# 130: Taberna Almendro 13 (0.86km)
# 131: Casa Labra (0.87km)
# 132: Taberna El Gallocanta (0.87km)
# 133: La Verónica (0.87km)
# 134: Restaurante Esteban (0.87km)
# 135: Doña Luz (0.87km)
# 136: Taberna Los Gatos (0.88km)
# 137: El Rincón de Esteban (0.88km)
# 138: Bodega de Los Secretos (0.88km)
# 139: Dani Brasserie (0.88km)
# 140: Kirei Las Cortes  (0.88km)
# 141: Taberna de la Dolores (0.88km)
# 142: Yugo the Bunker (0.89km)
# 143: Taberna El Tempranillo (0.89km)
# 144: East 47 (0.89km)
# 145: Los Rotos (0.9km)
# 146: Grazie Mille Kitchen Bar  (0.9km)
# 147: Magerit (0.91km)
# 148: Lamiak (0.91km)
# 149: Casa Lucio (0.91km)
# 150: Cervecería Cervantes (0.91km)
# 151: El Escaldón (0.91km)
# 152: Casa Rua (0.92km)
# 153: Askuabarra (0.92km)
# 154: Paco Roncero Restaurante (0.94km)
# 155: Valle Del Tietar (0.94km)
# 156: Havana Blues (0.94km)
# 157: La Ancha (Zorrilla) (0.95km)
# 158: Arzabal (Reina Sofía) (0.95km)
# 159: Yerbabuena (0.95km)
# 160: Gran Café de Madrid (0.95km)
# 161: Robin Hood (0.95km)
# 162: El Ñeru (0.96km)
# 163: Vinos 11 Casa Dani (0.96km)
# 164: La Platería (0.97km)
# 165: Juana la Loca (0.97km)
# 166: Casa Mortero (0.99km)
# 167: The Cask (0.99km)
# 168: Trattoria Pinocchio (Sánchez Bustillo) (0.99km)
# 169: Taste Gallery (1.0km)
#
# Escoja una opción: 1
# Nombre:
# Melo´s
# E-mail:
# contacto@melosbar.es
# Teléfono:
# (+34) 91 527 50 54
# Descripción:
# Situado en el barrio de Lavapiés, este popular bar con marcado acento gallego lleva ofreciendo desde finales de la década de 1970 a sus clientes abundantes raciones elaboradas con una gran calidad, destacando sus conocidas "zapatillas": pan gallego tostado con lacón y queso de tetilla fundido. En 2021 sus antiguos dueños traspasaron su local y, desde entonces, Rafael Riqueni, Alejandro Martínez e Ignacio Revuelta se encargan de que el espíritu de esta institución gastronómica madrileña perviva.La pequeña carta del Melo's cuenta entre sus propuestas más destacadas con unas cremosas croquetas de jamón, pimientos del padrón y empanadillas de tomate, bonito y huevo.El local no admite reservas.
# Página web:
# https://www.esmadrid.com/restaurantes/melo-s
# Localizacion:
# del Ave María, 44.Madrid, 28012
# Tipo de cocina:
# Tapas : Tapas
# Horario:  Lun - Dom: 13:00 - 16:30 h / 19:30 - 23:45 hHorario verano (27 jun - 4 sept):Lun - Jue: 20:00 - 23:45 hVier - Sáb: 20:00 - 24:15 h
#
# Quiere realizar otra búsqueda (si/no): si
# Introduce una calle: cava baja
# Introduce la distancia máxima en km: 1
# -------------------------------------------------
# 1: Taberna Casa Curro (0.02km)
# 2: Casa Victor   (0.02km)
# 3: La Perejila (0.03km)
# 4: Matritum (0.04km)
# 5: Huevos de Lucio (0.04km)
# 6: Casa Lucas (0.04km)
# 7: Casa Julián de Tolosa (Cava Baja) (0.05km)
# 8: Taberna Almendro 13 (0.07km)
# 9: Viejo Madrid (0.07km)
# 10: Casa María  (0.07km)
# 11: La Antoñita (0.09km)
# 12: Enotaberna del León de Oro (0.09km)
# 13: Posada de la Villa (0.1km)
# 14: La Taberna del Capitán Alatriste (0.1km)
# 15: Restaurante Esteban (0.11km)
# 16: El Escaldón (0.12km)
# 17: Taberna El Tempranillo (0.13km)
# 18: Lamiak (0.16km)
# 19: Casa Lucio (0.16km)
# 20: Robin Hood (0.16km)
# 21: Casa Paco (0.17km)
# 22: La Huerta de Almería (0.2km)
# 23: Oliveros (0.2km)
# 24: La Bobia (0.21km)
# 25: Botín (0.21km)
# 26: Casa Revuelta (0.21km)
# 27: Bodegas Ricla (0.22km)
# 28: Cascorro Bistrot (0.24km)
# 29: La más croqueta (0.25km)
# 30: Taberna La Daniela  (0.25km)
# 31: Juana la Loca (0.25km)
# 32: Las Cuevas de Luis Candelas (0.26km)
# 33: Naia Bistro (0.26km)
# 34: La Mordida de Segovia (0.26km)
# 35: Bahiana (0.27km)
# 36: Yan Ken Pon (0.29km)
# 37: Malacatín (0.29km)
# 38: Taberna Corrientes (0.3km)
# 39: Doña Truhana (0.3km)
# 40: Gustos Madrid Plaza Mayor (0.3km)
# 41: El Estragón Vegetariano (0.3km)
# 42: Delic (0.31km)
# 43: Viva Burger  (0.31km)
# 44: La Musa Latina (0.32km)
# 45: Taste Gallery (0.32km)
# 46: Hong Kong 70 (0.33km)
# 47: Bar Santurce (0.34km)
# 48: Metro Bistro (Plaza Mayor) (0.35km)
# 49: Taquería del Alamillo (0.35km)
# 50: Magerit (0.36km)
# 51: El Imparcial (0.36km)
# 52: Casa Rua (0.36km)
# 53: Valle Del Tietar (0.36km)
# 54: La Campana (0.36km)
# 55: Cervecería Plaza Mayor 2 (0.36km)
# 56: La ideal (0.37km)
# 57: Citynizer Plaza (0.37km)
# 58: Los Galayos (0.38km)
# 59: Gran Café de Madrid (0.39km)
# 60: Liana 1962 (0.4km)
# 61: La Encomienda (0.4km)
# 62: Taberna Almería (0.41km)
# 63: Can Punyetes (Señores de Luzón) (0.41km)
# 64: El soportal (0.41km)
# 65: Salón de Tapas Plaza Mayor (0.42km)
# 66: Viuda de Vacas (0.42km)
# 67: Vinos 11 Casa Dani (0.43km)
# 68: Grazie Mille Kitchen Bar  (0.45km)
# 69: Restaurante Vegetariano (0.46km)
# 70: Taberneros (0.46km)
# 71: Yerbabuena (0.46km)
# 72: Casa Ciriaco (0.48km)
# 73: Taberna Rayuela (0.48km)
# 74: Ramen Kagura (0.48km)
# 75: Dans le noir? (0.49km)
# 76: Rasputín (0.49km)
# 77: El Buti Taberna (0.49km)
# 78: Taberna Antonio Sánchez (0.49km)
# 79: El Ñeru (0.5km)
# 80: Los Arrieros (0.5km)
# 81: Bar Postas (0.51km)
# 82: La Excéntrica  (0.54km)
# 83: El 5 de Tirso (0.54km)
# 84: La Esquina del Real (0.55km)
# 85: La cruzada (0.55km)
# 86: La Ópera de Madrid (0.55km)
# 87: ElMandela (0.56km)
# 88: Cervecería Sol Mayor (0.56km)
# 89: El Clásico (0.57km)
# 90: Algarabía (0.57km)
# 91: Taberna Dehesa Santa María (0.57km)
# 92: Corral de la Morería Restaurante Gastronómico (0.57km)
# 93: Cortezo Yatai Market (0.57km)
# 94: Asador Real (0.58km)
# 95: Los Caracoles (0.58km)
# 96: El Anciano Rey de los Vinos (0.59km)
# 97: Toma Jamón (Vergara) (0.6km)
# 98: Antigua Taquería (0.63km)
# 99: Restaurante de Casa de Castilla La Mancha en Madrid   (0.63km)
# 100: La Malaje (0.63km)
# 101: La casa de las torrijas (0.63km)
# 102: El Tormo (0.64km)
# 103: López & López  (0.64km)
# 104: Café de Oriente (0.66km)
# 105: Papagena (0.67km)
# 106: La Botillería (0.67km)
# 107: Albahía (0.67km)
# 108: El Landó (0.68km)
# 109: De Maria (Correo) (0.68km)
# 110: As Jamonería (0.68km)
# 111: Entre Suspiro y Suspiro (0.69km)
# 112: Taberna del Alabardero (0.7km)
# 113: Maestro Food & More (0.7km)
# 114: Antigua Embajada (Hotel Palacio San Martín) (0.71km)
# 115: El Café de la Ópera (0.71km)
# 116: Lambuzo (Conchas) (0.71km)
# 117: Bar El Pescador  (0.72km)
# 118: La Lonja del Mar (0.72km)
# 119: Casa Labra (0.72km)
# 120: Casa Jaguar (0.74km)
# 121: Puertalsol (0.75km)
# 122: Taberna del Chato (0.76km)
# 123: El Rincón Guay (0.78km)
# 124: Ginger (0.79km)
# 125: Dos Cielos Madrid (0.8km)
# 126: Montmartre 1889 (0.8km)
# 127: Cuando salí de Cuba (0.8km)
# 128: Café Varela Restaurante (Hotel Preciados) (0.82km)
# 129: Majaderitos Café (0.82km)
# 130: El Cucurucho del Mar (0.82km)
# 131: El Patio de la Central (La Central de Callao) (0.83km)
# 132: La Negra Tomasa (0.83km)
# 133: Inclán Brutal Bar (0.84km)
# 134: La Bola (0.84km)
# 135: Asador de Aranda (0.84km)
# 136: Gula Gula (0.85km)
# 137: Las Bravas (Álvarez Gato) (0.85km)
# 138: De María (Preciados) (0.86km)
# 139: Ana La Santa (0.88km)
# 140: Radio Rooftop (0.88km)
# 141: La Casa del Abuelo  (0.89km)
# 142: Las Bravas (Pje Matheu) (0.9km)
# 143: Mashita (0.9km)
# 144: La Terraza del Santo Domingo (0.91km)
# 145: Lateral  (0.91km)
# 146: Doña Luz (0.92km)
# 147: Melo´s (0.93km)
# 148: El Buey  (0.94km)
# 149: Las chicas, los chicos y los maniquís (0.95km)
# 150: Caripén (0.95km)
# 151: El Senador (0.95km)
# 152: La Rebonita (0.95km)
# 153: Vi Cool (0.95km)
# 154: Carl’s JR. (0.96km)
# 155: Tommy Mel's  (0.97km)
# 156: Lhardy (0.97km)
# 157: Five Guys (0.97km)
# 158: La Taurina (0.97km)
# 159: Bodegas Alfaro (0.98km)
# 160: Vietnam Mekong (0.98km)
# 161: Lamucca (Plaza del Carmen) (0.99km)
# 162: Cervecería Alemana  (1.0km)
# Escoja una opción: 76
# Nombre:
# Rasputín
# E-mail:
# restauranterasputin@hotmail.com
# Teléfono:
# (+34) 91 366 39 62
# Descripción:
# La comida rusa no tiene una representación muy extendida en Madrid pero hay algunas muestras de esta deliciosa gastronomía. Es el caso de este restaurante situado en el barrio de La Latina, muy cerca de la Plaza de la Paja.Ofrece un ambiente que parece extraído de otra época, decorado en tonos tierra y madera, tiene capacidad para 60 comensales, por lo que es ideal para una cena romántica. La comida es excelente y merece la pena pedir varios platos. Sabrosísimas creaciones gastronómicas entre las que destacan algunas de sus especialidades como el blinis con caviar negro y el strogonof de solomillo de ternera, entre su amplia oferta de platos. Dispone de una encantadora terraza donde poder disfrutar de agradables noches.
# Página web:
# https://www.esmadrid.com/restaurantes/rasputin
# Localizacion:
# Yeseros, 2.Madrid, 28005
# Tipo de cocina:
# Internacional : Rusa
# Horario:  Mar - Sáb: 13:30 - 16:00 h. / 21:00 - 0:00 h.Dom: 13:30 - 16:00 h.
#
# Quiere realizar otra búsqueda (si/no): no

# %% [markdown]
# Normas de entrega
#
#    * Fecha tope de entrega: 06/10/2022
#    * La entrega se realizará subiendo al campus virtual un notebook de Jupyter con la solución. El archivo tendrá como nombre FormatosII_GrupoX donde X será el número de grupo correspondiente.
